# %% [markdown]
# # Exploring NEMDE Input and Output Files

# %%
import os
import collections

import xmltodict

# %% [markdown]
# ### Load data

# %%
data_directory = os.path.join(os.path.dirname(os.path.curdir), os.path.pardir, os.path.pardir, 'data')
filename = 'NEMSPDOutputs_2019100100100.loaded'

with open(os.path.join(data_directory, filename)) as f:
    doc = xmltodict.parse(f.read())

# %% [markdown]
# Top-level keys

# %%
doc['NEMSPDCaseFile'].keys()
# Out:
# odict_keys(['NemSpdInputs', 'NemSpdOutputs', 'SolutionAnalysis'])

# %% [markdown]
# ## Inputs

# %%
doc['NEMSPDCaseFile']['NemSpdInputs'].keys()
# Out:
# odict_keys(['@VERSION', 'Case', 'RegionCollection', 'TraderCollection', 'InterconnectorCollection', 'ConstraintScadaDataCollection', 'GenericEquationCollection', 'GenericConstraintCollection', 'PeriodCollection', 'OCD_Required'])

# %% [markdown]
# #### Case information
# These may be global parameters for case run.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['Case']
# Out:
# OrderedDict([('@CaseID', '20191001001'),
#              ('@CaseType', 'DS'),
#              ('@Intervention', 'True'),
#              ('@VoLL', '14700'),
#              ('@MPF', '-1000'),
#              ('@EnergyDeficitPrice', '2205000'),
#              ('@EnergySurplusPrice', '2205000'),
#              ('@RampRatePrice', '16978500'),
#              ('@InterconnectorPrice', '16905000'),
#              ('@CapacityPrice', '5439000'),
#              ('@OfferPrice', '16684500'),
#              ('@TieBreakPrice', '1E-6'),
#              ('@GenericConstraintPrice', '441000'),
#              ('@NPLThreshold', '0.1'),
#              ('@MNSPLossesPrice', '5365500'),
#              ('@MNSPOfferPrice', '16684500'),
#              ('@MNSPRampRatePrice', '16978500'),
#              ('@MNSPCapacityPrice', '5365500'),
#              ('@FastStartPrice', '16611000'),
#              ('@Satisfactory_Network_Price', '5292000'),
#              ('@FastStartThreshold', '0.005'),
#              ('@SwitchRunInitialStatus', '1'),
#              ('@UIGFSurplusPrice', '5659500'),
#              ('@UIGF_ATime', '20191001040500'),
#              ('@UseSOS2LossModel', 'True'),
#              ('@ASProfilePrice', '2278500'),
#              ('@ASMaxAvailPrice', '2278500'),
#              ('@ASEnablementMinPrice', '1029000'),
#              ('@ASEnablementMaxPrice', '1029000')])

# %% [markdown]
# #### Region information
# Provides demand values / gives high level overview of demand in each region. Not sure how useful this is. Same information may be in ConstraintScadaDataCollection.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['RegionCollection']['Region']
# Out:
# [OrderedDict([('@RegionID', 'NSW1'),
#               ('RegionInitialConditionCollection',
#                OrderedDict([('RegionInitialCondition',
#                              [OrderedDict([('@InitialConditionID', 'ADE'),
#                                            ('@Value', '0')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'InitialDemand'),
#                                            ('@Value',
#                                             '6273.9912109375')])])]))]),
#  OrderedDict([('@RegionID', 'QLD1'),
#               ('RegionInitialConditionCollection',
#                OrderedDict([('RegionInitialCondition',
#                              [OrderedDict([('@InitialConditionID', 'ADE'),
#                                            ('@Value', '0')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'InitialDemand'),
#                                            ('@Value',
#                                             '5153.67138671875')])])]))]),
#  OrderedDict([('@RegionID', 'SA1'),
#               ('RegionInitialConditionCollection',
#                OrderedDict([('RegionInitialCondition',
#                              [OrderedDict([('@InitialConditionID', 'ADE'),
#                                            ('@Value', '0')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'InitialDemand'),
#                                            ('@Value',
#                                             '1117.24145507812')])])]))]),
#  OrderedDict([('@RegionID', 'TAS1'),
#               ('RegionInitialConditionCollection',
#                OrderedDict([('RegionInitialCondition',
#                              [OrderedDict([('@InitialConditionID', 'ADE'),
#                                            ('@Value', '1.37598323822021')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'InitialDemand'),
#                                            ('@Value',
#                                             '975.504638671875')])])]))]),
#  OrderedDict([('@RegionID', 'VIC1'),
#               ('RegionInitialConditionCollection',
#                OrderedDict([('RegionInitialCondition',
#                              [OrderedDict([('@InitialConditionID', 'ADE'),
#                                            ('@Value', '0')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'InitialDemand'),
#                                            ('@Value', '4365.1328125')])])]))])]

# %% [markdown]
# #### Trader information
# Provides price bands for each unit. Note that loads and generators are included. Different price bands depending on energy and ancillary service market offers.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['TraderCollection']['Trader'][-1:]
# Out:
# [OrderedDict([('@TraderID', 'YWPS4'),
#               ('@TraderType', 'GENERATOR'),
#               ('@SemiDispatch', '0'),
#               ('TraderInitialConditionCollection',
#                OrderedDict([('TraderInitialCondition',
#                              [OrderedDict([('@InitialConditionID',
#                                             'AGCStatus'),
#                                            ('@Value', '1')]),
#                               OrderedDict([('@InitialConditionID', 'HMW'),
#                                            ('@Value', '400.21875')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'InitialMW'),
#                                            ('@Value', '385.358215332031')]),
#                               OrderedDict([('@InitialConditionID', 'LMW'),
#                                            ('@Value', '150.46875')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'SCADARampDnRate'),
#                                            ('@Value', '300.374994277954')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'SCADARampUpRate'),
#                                            ('@Value', '300.374994277954')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'WhatIfInitialMW'),
#                                            ('@Value', '385')])])])),
#               ('TradePriceStructureCollection',
#                OrderedDict([('TradePriceStructure',
#                              OrderedDict([('@TradePriceStructureID',
#                                            '20191001001'),
#                                           ('TradeTypePriceStructureCollection',
#                                            OrderedDict([('TradeTypePriceStructure',
#                                                          [OrderedDict([('@TradeType',
#                                                                         'ENOF'),
#                                                                        ('@PriceBand1',
#                                                                         '-1000'),
#                                                                        ('@PriceBand2',
#                                                                         '0'),
#                                                                        ('@PriceBand3',
#                                                                         '9.18'),
#                                                                        ('@PriceBand4',
#                                                                         '16.15'),
#                                                                        ('@PriceBand5',
#                                                                         '25.14'),
#                                                                        ('@PriceBand6',
#                                                                         '34.81'),
#                                                                        ('@PriceBand7',
#                                                                         '83.66'),
#                                                                        ('@PriceBand8',
#                                                                         '283.83'),
#                                                                        ('@PriceBand9',
#                                                                         '12681.81'),
#                                                                        ('@PriceBand10',
#                                                                         '13776.8'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-30T23:06:58+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '9')]),
#                                                           OrderedDict([('@TradeType',
#                                                                         'L5MI'),
#                                                                        ('@PriceBand1',
#                                                                         '0.08'),
#                                                                        ('@PriceBand2',
#                                                                         '0.17'),
#                                                                        ('@PriceBand3',
#                                                                         '0.79'),
#                                                                        ('@PriceBand4',
#                                                                         '1.19'),
#                                                                        ('@PriceBand5',
#                                                                         '4.4'),
#                                                                        ('@PriceBand6',
#                                                                         '9.99'),
#                                                                        ('@PriceBand7',
#                                                                         '29.99'),
#                                                                        ('@PriceBand8',
#                                                                         '99.99'),
#                                                                        ('@PriceBand9',
#                                                                         '249.9'),
#                                                                        ('@PriceBand10',
#                                                                         '8999.99'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-24T10:51:55+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '8')]),
#                                                           OrderedDict([('@TradeType',
#                                                                         'L5RE'),
#                                                                        ('@PriceBand1',
#                                                                         '0.05'),
#                                                                        ('@PriceBand2',
#                                                                         '1.9'),
#                                                                        ('@PriceBand3',
#                                                                         '4.78'),
#                                                                        ('@PriceBand4',
#                                                                         '9.4'),
#                                                                        ('@PriceBand5',
#                                                                         '14'),
#                                                                        ('@PriceBand6',
#                                                                         '29'),
#                                                                        ('@PriceBand7',
#                                                                         '64.9'),
#                                                                        ('@PriceBand8',
#                                                                         '240.9'),
#                                                                        ('@PriceBand9',
#                                                                         '11990'),
#                                                                        ('@PriceBand10',
#                                                                         '14600'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-24T10:51:55+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '8')]),
#                                                           OrderedDict([('@TradeType',
#                                                                         'L60S'),
#                                                                        ('@PriceBand1',
#                                                                         '0.08'),
#                                                                        ('@PriceBand2',
#                                                                         '0.17'),
#                                                                        ('@PriceBand3',
#                                                                         '0.29'),
#                                                                        ('@PriceBand4',
#                                                                         '0.94'),
#                                                                        ('@PriceBand5',
#                                                                         '2.9'),
#                                                                        ('@PriceBand6',
#                                                                         '9.99'),
#                                                                        ('@PriceBand7',
#                                                                         '29'),
#                                                                        ('@PriceBand8',
#                                                                         '99'),
#                                                                        ('@PriceBand9',
#                                                                         '4600'),
#                                                                        ('@PriceBand10',
#                                                                         '9899'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-24T10:51:55+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '8')]),
#                                                           OrderedDict([('@TradeType',
#                                                                         'L6SE'),
#                                                                        ('@PriceBand1',
#                                                                         '0.03'),
#                                                                        ('@PriceBand2',
#                                                                         '0.05'),
#                                                                        ('@PriceBand3',
#                                                                         '0.16'),
#                                                                        ('@PriceBand4',
#                                                                         '0.3'),
#                                                                        ('@PriceBand5',
#                                                                         '1.9'),
#                                                                        ('@PriceBand6',
#                                                                         '25.04'),
#                                                                        ('@PriceBand7',
#                                                                         '30.04'),
#                                                                        ('@PriceBand8',
#                                                                         '99'),
#                                                                        ('@PriceBand9',
#                                                                         '4600'),
#                                                                        ('@PriceBand10',
#                                                                         '9899'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-24T10:51:55+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '8')]),
#                                                           OrderedDict([('@TradeType',
#                                                                         'R5MI'),
#                                                                        ('@PriceBand1',
#                                                                         '0.05'),
#                                                                        ('@PriceBand2',
#                                                                         '1.78'),
#                                                                        ('@PriceBand3',
#                                                                         '4.48'),
#                                                                        ('@PriceBand4',
#                                                                         '14.5'),
#                                                                        ('@PriceBand5',
#                                                                         '30.03'),
#                                                                        ('@PriceBand6',
#                                                                         '49'),
#                                                                        ('@PriceBand7',
#                                                                         '87.7'),
#                                                                        ('@PriceBand8',
#                                                                         '100'),
#                                                                        ('@PriceBand9',
#                                                                         '11990'),
#                                                                        ('@PriceBand10',
#                                                                         '12400.4'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-24T10:51:55+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '8')]),
#                                                           OrderedDict([('@TradeType',
#                                                                         'R5RE'),
#                                                                        ('@PriceBand1',
#                                                                         '0.05'),
#                                                                        ('@PriceBand2',
#                                                                         '2.7'),
#                                                                        ('@PriceBand3',
#                                                                         '9.99'),
#                                                                        ('@PriceBand4',
#                                                                         '19.99'),
#                                                                        ('@PriceBand5',
#                                                                         '49'),
#                                                                        ('@PriceBand6',
#                                                                         '95.5'),
#                                                                        ('@PriceBand7',
#                                                                         '240'),
#                                                                        ('@PriceBand8',
#                                                                         '450.5'),
#                                                                        ('@PriceBand9',
#                                                                         '950.5'),
#                                                                        ('@PriceBand10',
#                                                                         '11900'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-24T10:51:55+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '8')]),
#                                                           OrderedDict([('@TradeType',
#                                                                         'R60S'),
#                                                                        ('@PriceBand1',
#                                                                         '0.17'),
#                                                                        ('@PriceBand2',
#                                                                         '1.8'),
#                                                                        ('@PriceBand3',
#                                                                         '4.8'),
#                                                                        ('@PriceBand4',
#                                                                         '10.01'),
#                                                                        ('@PriceBand5',
#                                                                         '21'),
#                                                                        ('@PriceBand6',
#                                                                         '39'),
#                                                                        ('@PriceBand7',
#                                                                         '52'),
#                                                                        ('@PriceBand8',
#                                                                         '102'),
#                                                                        ('@PriceBand9',
#                                                                         '4400'),
#                                                                        ('@PriceBand10',
#                                                                         '11999'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-24T10:51:55+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '8')]),
#                                                           OrderedDict([('@TradeType',
#                                                                         'R6SE'),
#                                                                        ('@PriceBand1',
#                                                                         '0.48'),
#                                                                        ('@PriceBand2',
#                                                                         '1.75'),
#                                                                        ('@PriceBand3',
#                                                                         '4.9'),
#                                                                        ('@PriceBand4',
#                                                                         '20.7'),
#                                                                        ('@PriceBand5',
#                                                                         '33.33'),
#                                                                        ('@PriceBand6',
#                                                                         '99.9'),
#                                                                        ('@PriceBand7',
#                                                                         '630'),
#                                                                        ('@PriceBand8',
#                                                                         '1999'),
#                                                                        ('@PriceBand9',
#                                                                         '6000'),
#                                                                        ('@PriceBand10',
#                                                                         '12299'),
#                                                                        ('@Offer_SettlementDate',
#                                                                         '2019-10-01T00:00:00+10:00'),
#                                                                        ('@Offer_EffectiveDate',
#                                                                         '2019-09-24T10:51:55+10:00'),
#                                                                        ('@Offer_VersionNo',
#                                                                         '8')])])]))]))]))])]

# %% [markdown]
# #### Interconnector information
# Provide initial flow over interconnector. Also provides loss model information. Not sure how this is calculated though. Seem to be different segments depending on the lmit, and perhaps a changing loss factor also.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['InterconnectorCollection']['Interconnector'][:2]
# Out:
# [OrderedDict([('@InterconnectorID', 'N-Q-MNSP1'),
#               ('InterconnectorInitialConditionCollection',
#                OrderedDict([('InterconnectorInitialCondition',
#                              [OrderedDict([('@InitialConditionID',
#                                             'InitialMW'),
#                                            ('@Value', '-107.800003051758')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'WhatIfInitialMW'),
#                                            ('@Value', '-115.01637')])])])),
#               ('LossModelCollection',
#                OrderedDict([('LossModel',
#                              OrderedDict([('@LossModelID',
#                                            '637054995000000000'),
#                                           ('@LossLowerLimit', '265'),
#                                           ('@LossShare', '0.54'),
#                                           ('@NPLRange', '10000'),
#                                           ('SegmentCollection',
#                                            OrderedDict([('Segment',
#                                                          [OrderedDict([('@Limit',
#                                                                         '-257'),
#                                                                        ('@Factor',
#                                                                         '-0.646752800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-249'),
#                                                                        ('@Factor',
#                                                                         '-0.625914400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-241'),
#                                                                        ('@Factor',
#                                                                         '-0.605076000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-233'),
#                                                                        ('@Factor',
#                                                                         '-0.584237600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-225'),
#                                                                        ('@Factor',
#                                                                         '-0.563399200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-217'),
#                                                                        ('@Factor',
#                                                                         '-0.542560800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-209'),
#                                                                        ('@Factor',
#                                                                         '-0.521722400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-201'),
#                                                                        ('@Factor',
#                                                                         '-0.500884000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-193'),
#                                                                        ('@Factor',
#                                                                         '-0.480045600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-185'),
#                                                                        ('@Factor',
#                                                                         '-0.459207200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-177'),
#                                                                        ('@Factor',
#                                                                         '-0.438368800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-169'),
#                                                                        ('@Factor',
#                                                                         '-0.417530400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-161'),
#                                                                        ('@Factor',
#                                                                         '-0.396692000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-153'),
#                                                                        ('@Factor',
#                                                                         '-0.375853600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-145'),
#                                                                        ('@Factor',
#                                                                         '-0.355015200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-137'),
#                                                                        ('@Factor',
#                                                                         '-0.334176800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-129'),
#                                                                        ('@Factor',
#                                                                         '-0.313338400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-121'),
#                                                                        ('@Factor',
#                                                                         '-0.292500000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-113'),
#                                                                        ('@Factor',
#                                                                         '-0.271661600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-105'),
#                                                                        ('@Factor',
#                                                                         '-0.250823200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-97'),
#                                                                        ('@Factor',
#                                                                         '-0.229984800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-89'),
#                                                                        ('@Factor',
#                                                                         '-0.209146400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-81'),
#                                                                        ('@Factor',
#                                                                         '-0.188308000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-73'),
#                                                                        ('@Factor',
#                                                                         '-0.167469600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-65'),
#                                                                        ('@Factor',
#                                                                         '-0.146631200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-57'),
#                                                                        ('@Factor',
#                                                                         '-0.125792800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-49'),
#                                                                        ('@Factor',
#                                                                         '-0.104954400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-41'),
#                                                                        ('@Factor',
#                                                                         '-0.084116000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-33'),
#                                                                        ('@Factor',
#                                                                         '-0.063277600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-25'),
#                                                                        ('@Factor',
#                                                                         '-0.042439200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-17'),
#                                                                        ('@Factor',
#                                                                         '-0.021600800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-9'),
#                                                                        ('@Factor',
#                                                                         '-0.000762400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '0'),
#                                                                        ('@Factor',
#                                                                         '0.021378400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '9'),
#                                                                        ('@Factor',
#                                                                         '0.044821600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '17'),
#                                                                        ('@Factor',
#                                                                         '0.066962400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '25'),
#                                                                        ('@Factor',
#                                                                         '0.087800800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '33'),
#                                                                        ('@Factor',
#                                                                         '0.108639200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '41'),
#                                                                        ('@Factor',
#                                                                         '0.129477600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '49'),
#                                                                        ('@Factor',
#                                                                         '0.150316000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '57'),
#                                                                        ('@Factor',
#                                                                         '0.171154400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '65'),
#                                                                        ('@Factor',
#                                                                         '0.191992800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '73'),
#                                                                        ('@Factor',
#                                                                         '0.212831200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '81'),
#                                                                        ('@Factor',
#                                                                         '0.233669600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '89'),
#                                                                        ('@Factor',
#                                                                         '0.254508000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '97'),
#                                                                        ('@Factor',
#                                                                         '0.275346400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '105'),
#                                                                        ('@Factor',
#                                                                         '0.296184800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '113'),
#                                                                        ('@Factor',
#                                                                         '0.317023200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '121'),
#                                                                        ('@Factor',
#                                                                         '0.337861600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '129'),
#                                                                        ('@Factor',
#                                                                         '0.358700000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '137'),
#                                                                        ('@Factor',
#                                                                         '0.379538400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '145'),
#                                                                        ('@Factor',
#                                                                         '0.400376800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '153'),
#                                                                        ('@Factor',
#                                                                         '0.421215200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '161'),
#                                                                        ('@Factor',
#                                                                         '0.442053600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '169'),
#                                                                        ('@Factor',
#                                                                         '0.462892000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '177'),
#                                                                        ('@Factor',
#                                                                         '0.483730400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '185'),
#                                                                        ('@Factor',
#                                                                         '0.504568800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '193'),
#                                                                        ('@Factor',
#                                                                         '0.525407200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '201'),
#                                                                        ('@Factor',
#                                                                         '0.546245600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '209'),
#                                                                        ('@Factor',
#                                                                         '0.567084000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '217'),
#                                                                        ('@Factor',
#                                                                         '0.587922400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '225'),
#                                                                        ('@Factor',
#                                                                         '0.608760800')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '233'),
#                                                                        ('@Factor',
#                                                                         '0.629599200')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '241'),
#                                                                        ('@Factor',
#                                                                         '0.650437600')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '249'),
#                                                                        ('@Factor',
#                                                                         '0.671276000')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '257'),
#                                                                        ('@Factor',
#                                                                         '0.692114400')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '265'),
#                                                                        ('@Factor',
#                                                                         '0.712952800')])])]))]))]))]),
#  OrderedDict([('@InterconnectorID', 'NSW1-QLD1'),
#               ('InterconnectorInitialConditionCollection',
#                OrderedDict([('InterconnectorInitialCondition',
#                              [OrderedDict([('@InitialConditionID',
#                                             'InitialMW'),
#                                            ('@Value', '-842.864501953125')]),
#                               OrderedDict([('@InitialConditionID',
#                                             'WhatIfInitialMW'),
#                                            ('@Value', '-847.58464')])])])),
#               ('LossModelCollection',
#                OrderedDict([('LossModel',
#                              OrderedDict([('@LossModelID',
#                                            '637054995000000000'),
#                                           ('@LossLowerLimit', '1660'),
#                                           ('@LossShare', '0.56'),
#                                           ('@NPLRange', '10000'),
#                                           ('SegmentCollection',
#                                            OrderedDict([('Segment',
#                                                          [OrderedDict([('@Limit',
#                                                                         '-1626'),
#                                                                        ('@Factor',
#                                                                         '-0.319658207')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1592'),
#                                                                        ('@Factor',
#                                                                         '-0.312988427')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1558'),
#                                                                        ('@Factor',
#                                                                         '-0.306318647')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1524'),
#                                                                        ('@Factor',
#                                                                         '-0.299648867')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1490'),
#                                                                        ('@Factor',
#                                                                         '-0.292979087')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1456'),
#                                                                        ('@Factor',
#                                                                         '-0.286309307')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1422'),
#                                                                        ('@Factor',
#                                                                         '-0.279639527')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1388'),
#                                                                        ('@Factor',
#                                                                         '-0.272969747')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1354'),
#                                                                        ('@Factor',
#                                                                         '-0.266299967')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1320'),
#                                                                        ('@Factor',
#                                                                         '-0.259630187')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1286'),
#                                                                        ('@Factor',
#                                                                         '-0.252960407')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1252'),
#                                                                        ('@Factor',
#                                                                         '-0.246290627')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1218'),
#                                                                        ('@Factor',
#                                                                         '-0.239620847')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1184'),
#                                                                        ('@Factor',
#                                                                         '-0.232951067')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1150'),
#                                                                        ('@Factor',
#                                                                         '-0.226281287')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1116'),
#                                                                        ('@Factor',
#                                                                         '-0.219611507')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1082'),
#                                                                        ('@Factor',
#                                                                         '-0.212941727')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1048'),
#                                                                        ('@Factor',
#                                                                         '-0.206271947')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-1014'),
#                                                                        ('@Factor',
#                                                                         '-0.199602167')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-980'),
#                                                                        ('@Factor',
#                                                                         '-0.192932387')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-946'),
#                                                                        ('@Factor',
#                                                                         '-0.186262607')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-912'),
#                                                                        ('@Factor',
#                                                                         '-0.179592827')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-878'),
#                                                                        ('@Factor',
#                                                                         '-0.172923047')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-844'),
#                                                                        ('@Factor',
#                                                                         '-0.166253267')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-810'),
#                                                                        ('@Factor',
#                                                                         '-0.159583487')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-776'),
#                                                                        ('@Factor',
#                                                                         '-0.152913707')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-742'),
#                                                                        ('@Factor',
#                                                                         '-0.146243927')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-708'),
#                                                                        ('@Factor',
#                                                                         '-0.139574147')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-674'),
#                                                                        ('@Factor',
#                                                                         '-0.132904367')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-640'),
#                                                                        ('@Factor',
#                                                                         '-0.126234587')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-606'),
#                                                                        ('@Factor',
#                                                                         '-0.119564807')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-572'),
#                                                                        ('@Factor',
#                                                                         '-0.112895027')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-538'),
#                                                                        ('@Factor',
#                                                                         '-0.106225247')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-504'),
#                                                                        ('@Factor',
#                                                                         '-0.099555467')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-470'),
#                                                                        ('@Factor',
#                                                                         '-0.092885687')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-436'),
#                                                                        ('@Factor',
#                                                                         '-0.086215907')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-402'),
#                                                                        ('@Factor',
#                                                                         '-0.079546127')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-368'),
#                                                                        ('@Factor',
#                                                                         '-0.072876347')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-334'),
#                                                                        ('@Factor',
#                                                                         '-0.066206567')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-300'),
#                                                                        ('@Factor',
#                                                                         '-0.059536787')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-266'),
#                                                                        ('@Factor',
#                                                                         '-0.052867007')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-232'),
#                                                                        ('@Factor',
#                                                                         '-0.046197227')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-198'),
#                                                                        ('@Factor',
#                                                                         '-0.039527447')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-164'),
#                                                                        ('@Factor',
#                                                                         '-0.032857667')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-130'),
#                                                                        ('@Factor',
#                                                                         '-0.026187887')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-96'),
#                                                                        ('@Factor',
#                                                                         '-0.019518107')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-62'),
#                                                                        ('@Factor',
#                                                                         '-0.012848327')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '-28'),
#                                                                        ('@Factor',
#                                                                         '-0.006178547')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '6'),
#                                                                        ('@Factor',
#                                                                         '0.000491233')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '40'),
#                                                                        ('@Factor',
#                                                                         '0.007161013')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '74'),
#                                                                        ('@Factor',
#                                                                         '0.013830793')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '108'),
#                                                                        ('@Factor',
#                                                                         '0.020500573')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '142'),
#                                                                        ('@Factor',
#                                                                         '0.027170353')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '176'),
#                                                                        ('@Factor',
#                                                                         '0.033840133')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '210'),
#                                                                        ('@Factor',
#                                                                         '0.040509913')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '244'),
#                                                                        ('@Factor',
#                                                                         '0.047179693')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '278'),
#                                                                        ('@Factor',
#                                                                         '0.053849473')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '312'),
#                                                                        ('@Factor',
#                                                                         '0.060519253')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '346'),
#                                                                        ('@Factor',
#                                                                         '0.067189033')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '380'),
#                                                                        ('@Factor',
#                                                                         '0.073858813')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '414'),
#                                                                        ('@Factor',
#                                                                         '0.080528593')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '448'),
#                                                                        ('@Factor',
#                                                                         '0.087198373')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '482'),
#                                                                        ('@Factor',
#                                                                         '0.093868153')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '516'),
#                                                                        ('@Factor',
#                                                                         '0.100537933')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '550'),
#                                                                        ('@Factor',
#                                                                         '0.107207713')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '584'),
#                                                                        ('@Factor',
#                                                                         '0.113877493')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '618'),
#                                                                        ('@Factor',
#                                                                         '0.120547273')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '652'),
#                                                                        ('@Factor',
#                                                                         '0.127217053')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '686'),
#                                                                        ('@Factor',
#                                                                         '0.133886833')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '720'),
#                                                                        ('@Factor',
#                                                                         '0.140556613')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '754'),
#                                                                        ('@Factor',
#                                                                         '0.147226393')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '788'),
#                                                                        ('@Factor',
#                                                                         '0.153896173')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '822'),
#                                                                        ('@Factor',
#                                                                         '0.160565953')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '856'),
#                                                                        ('@Factor',
#                                                                         '0.167235733')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '890'),
#                                                                        ('@Factor',
#                                                                         '0.173905513')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '924'),
#                                                                        ('@Factor',
#                                                                         '0.180575293')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '958'),
#                                                                        ('@Factor',
#                                                                         '0.187245073')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '992'),
#                                                                        ('@Factor',
#                                                                         '0.193914853')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '1026'),
#                                                                        ('@Factor',
#                                                                         '0.200584633')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '1060'),
#                                                                        ('@Factor',
#                                                                         '0.207254413')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '1094'),
#                                                                        ('@Factor',
#                                                                         '0.213924193')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '1128'),
#                                                                        ('@Factor',
#                                                                         '0.220593973')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '1162'),
#                                                                        ('@Factor',
#                                                                         '0.227263753')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '1196'),
#                                                                        ('@Factor',
#                                                                         '0.233933533')]),
#                                                           OrderedDict([('@Limit',
#                                                                         '1230'),
#                                                                        ('@Factor',
#                                                                         '0.240603313')])])]))]))]))])]

# %% [markdown]
# #### Constraint SCADA Data
# Coefficients in constraints take on values given by these dictionaries. Outer dict has seven entries. Each corresponds to a different type of SPDType.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['ConstraintScadaDataCollection']['ConstraintScadaData'][0]
# Out:
# OrderedDict([('@SpdType', 'A'),
#              ('ScadaValuesCollection',
#               OrderedDict([('ScadaValues',
#                             [OrderedDict([('@SpdID', '220_GEN_INERTIA'),
#                                           ('@Value', '25.4020004272461'),
#                                           ('@EMS_ID', 'INER'),
#                                           ('@EMS_Key', 'YPS.SUMM.BASE.INER'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD2'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:32:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', '500_GEN_INERTIA'),
#                                           ('@Value', '96.9560012817383'),
#                                           ('@EMS_ID', 'INER'),
#                                           ('@EMS_Key',
#                                            'MARKET.V_H_EX.5_59*500GENS.INER'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'True'),
#                                           ('@Data_Flags', '539033856'),
#                                           ('@Site_ID', 'EMS_PROD2'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:32:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'ANGAST1_INER'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'INER'),
#                                           ('@EMS_Key', 'ANGAST.GEN.AG_1.INER'),
#                                           ('@Grouping_ID', 'SA1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-09-30T10:30:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'ANGAST2_INER'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'INER'),
#                                           ('@EMS_Key', 'ANGAST.GEN.AG_2.INER'),
#                                           ('@Grouping_ID', 'SA1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-09-30T10:30:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'APD01_LOAD'),
#                                           ('@Value', '281.600006103516'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'APD.LOAD.LD_PL1.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '282.479583740234'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'APD02_LOAD'),
#                                           ('@Value', '191'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'APD.LOAD.LD_PL2.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '191.479583740234'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'APDLOAD'),
#                                           ('@Value', '-480.799987792969'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'APD.SUMM.500KV_LINES.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'APDLOAD_MVAR'),
#                                           ('@Value', '-291.200012207031'),
#                                           ('@EMS_ID', 'MVAR'),
#                                           ('@EMS_Key',
#                                            'APD.SUMM.500KV_LINES.MVAR'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'ARTX_SUM_LOAD'),
#                                           ('@Value', '8.17498779296875'),
#                                           ('@EMS_ID', 'MWF'),
#                                           ('@EMS_Key',
#                                            'ARMIDALE.SUMM.TRANS.MWF'),
#                                           ('@Grouping_ID', 'NSW1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'AUFLS2_MAX_R6'),
#                                           ('@Value', '27.1800003051758'),
#                                           ('@EMS_ID', 'R6'),
#                                           ('@EMS_Key', 'TAS1.AUFLS2.RAISE.R6'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BATS_B1HV_MW'),
#                                           ('@Value', '30'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'BATS.CB.B1TR_2B_220.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '38.4153366088867'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BATS_B2HV_MW'),
#                                           ('@Value', '31.6000003814697'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'BATS.CB.B2TR_1B_220.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '39.2148017883301'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BATS_TX_MW_SUMM'),
#                                           ('@Value', '-61.2999992370605'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'BATS.SUMM.TRANS_66.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BAYSW_SUMM_INERT'),
#                                           ('@Value', '74.3999938964844'),
#                                           ('@EMS_ID', 'INER'),
#                                           ('@EMS_Key',
#                                            'BAYSWATR.SUMM.BASE.INER'),
#                                           ('@Grouping_ID', 'NSW1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD2'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:32:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BLOWERING_INERT'),
#                                           ('@Value', '2.59999990463257'),
#                                           ('@EMS_ID', 'INER'),
#                                           ('@EMS_Key', 'BLOWERG.UNIT.1.INER'),
#                                           ('@Grouping_ID', 'NSW1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD2'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:32:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'BLUFF_PT_GEN'),
#                                           ('@Value', '0.919999957084656'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'WOOL_NTH.TRANS.T1.MW'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0.979084372520447'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BL_PREVDI_TARGET'),
#                                           ('@Value', '-195'),
#                                           ('@EMS_ID', 'MWB'),
#                                           ('@EMS_Key',
#                                            'BLGC.LINE.BASSLINK.MWB'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:55:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BL_RPC_Q_HMW'),
#                                           ('@Value', '76.8990783691406'),
#                                           ('@EMS_ID', 'HMW'),
#                                           ('@EMS_Key',
#                                            'GTCS.LINE.BASSLINK_RPCQ.HMW'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'BL_RPC_Q_LMW'),
#                                           ('@Value', '-692.068725585938'),
#                                           ('@EMS_ID', 'LMW'),
#                                           ('@EMS_Key',
#                                            'GTCS.LINE.BASSLINK_RPCQ.LMW'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'BOYNE_LOAD'),
#                                           ('@Value', '812.145446777344'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'H8_BOYNE.SUMM.TOTAL_LOAD.MW'),
#                                           ('@Grouping_ID', 'QLD1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:54:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'BRKNHIL.GT1'),
#                                           ('@Value', '0.0298271179199219'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'BRKNHILL.UNIT.GT1.MW'),
#                                           ('@Grouping_ID', 'NSW1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD2'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:43:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'BRKNHILLGT2'),
#                                           ('@Value', '-0.0206336975097656'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'BRKNHILL.UNIT.GT2.MW'),
#                                           ('@Grouping_ID', 'NSW1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD2'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:43:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'BSP_BBD_MW'),
#                                           ('@Value', '1.70000004768372'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'BSP.LOAD.LD_BBD.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '1.79999995231628'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BULGANA_WF_MW'),
#                                           ('@Value', '0.109999999403954'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'BGWF.GEN.BULGANA1.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:58:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BUTLERSG_GEN'),
#                                           ('@Value', '9.89999866485596'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'BUTLERS.UNIT.M/C.MW'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '9.8886833190918'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'BU_SH1_LINE_220KV'),
#                                           ('@Value', '229.56999206543'),
#                                           ('@EMS_ID', 'KV'),
#                                           ('@EMS_Key',
#                                            'BURNIE.LINE.SH_BU1.KV'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '228.96484375'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CANBERRA_TX_LOAD'),
#                                           ('@Value', '-180.674926757813'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'CANBERRA.SUMM.TRANS.MW'),
#                                           ('@Grouping_ID', 'NSW1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '-322.278991699219'),
#                                           ('@Est_Flags', '2050'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CANUNDA_MW'),
#                                           ('@Value', '5.8067741394043'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'SNUGGY.SUMM.CANUNDA.MW'),
#                                           ('@Grouping_ID', 'SA1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:15+10:00'),
#                                           ('@Est_Value', '1.30151998996735'),
#                                           ('@Est_Flags', '2050'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CAPITAL_GEN'),
#                                           ('@Value', '15.6000061035156'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'CAPITAL.UNIT.C1.MW'),
#                                           ('@Grouping_ID', 'NSW1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CATA1_GEN'),
#                                           ('@Value', '18.9600009918213'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'CATAGNYA.UNIT.M/C1.MW'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'CATA1_LOWOPLIM'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'LSP'),
#                                           ('@EMS_Key',
#                                            'CATAGNYA.UNIT.M/C1.LSP'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD2'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:32:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CATA2_GEN'),
#                                           ('@Value', '18.8700008392334'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'CATAGNYA.UNIT.M/C2.MW'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'CATA2_LOWOPLIM'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'LSP'),
#                                           ('@EMS_Key',
#                                            'CATAGNYA.UNIT.M/C2.LSP'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD2'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:32:15+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CATHROCK_MW'),
#                                           ('@Value', '40.439998626709'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'SLEAFD.SUMM.CATH_R.MW'),
#                                           ('@Grouping_ID', 'SA1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CBTS_TX_A1_MVA'),
#                                           ('@Value', '-323.633483886719'),
#                                           ('@EMS_ID', 'MVA'),
#                                           ('@EMS_Key',
#                                            'CBTS.TRANS.A1TR_220.MVA'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '-302.175750732422'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'CETHANA_GEN'),
#                                           ('@Value', '-1.50737500190735'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key', 'CETHANA.UNIT.M/C.MW'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '-0.137671276926994'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CHALLHWF_MW'),
#                                           ('@Value', '3.09999990463257'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'BGR.SUMM.CHALLICUM.MW'),
#                                           ('@Grouping_ID', 'VIC1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:55+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'True')]),
#                              OrderedDict([('@SpdID', 'CHAPEL_A_220_KV'),
#                                           ('@Value', '233.099990844727'),
#                                           ('@EMS_ID', 'KV'),
#                                           ('@EMS_Key',
#                                            'CHAPEL.BUS.220KV_BUS_A.KV'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
# ...
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '26.714714050293'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'QLINE746_H2SP_MVA'),
#                                           ('@Value', '3.58224725723267'),
#                                           ('@EMS_ID', 'MVA'),
#                                           ('@EMS_Key',
#                                            'H2_SPINE.LINE.110KV_746/1.MVA'),
#                                           ('@Grouping_ID', 'QLD1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '4.30213832855225'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'QLINE747/2_H5WO_MVA'),
#                                           ('@Value', '53.2756080627441'),
#                                           ('@EMS_ID', 'MVA'),
#                                           ('@EMS_Key',
#                                            'H5_WLGA.LINE.132KV_747/2.MVA'),
#                                           ('@Grouping_ID', 'QLD1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '47.7038993835449'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'QLINE747/2_H5WO_MW'),
#                                           ('@Value', '52.1569671630859'),
#                                           ('@EMS_ID', 'MW'),
#                                           ('@EMS_Key',
#                                            'H5_WLGA.LINE.132KV_747/2.MW'),
#                                           ('@Grouping_ID', 'QLD1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'True'),
#                                           ('@EMS_Good', 'True'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '1075904512'),
#                                           ('@Site_ID', 'EMS_PROD1'),
#                                           ('@Good_Input_Count', '2'),
#                                           ('@EMS_TimeStamp',
#                                            '2019-10-01T03:59:35+10:00'),
#                                           ('@Est_Value', '45.5256004333496'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'True'),
#                                           ('@IsReferenced', 'False')]),
#                              ...])])),
#              ('BadScadaValuesCollection',
#               OrderedDict([('ScadaValues',
#                             [OrderedDict([('@SpdID', 'MMSTIMESTAMP'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'TIME'),
#                                           ('@EMS_Key',
#                                            'MARKET.SOLVER.SOLUTION.TIME'),
#                                           ('@Grouping_ID', 'NEMMCO'),
#                                           ('@Can_Use_Last_Good', 'False'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'MMSTIMESTAMP_DS1'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'TIM1'),
#                                           ('@EMS_Key',
#                                            'MARKET.SOLVER.SOLUTION.TIM1'),
#                                           ('@Grouping_ID', 'NEMMCO'),
#                                           ('@Can_Use_Last_Good', 'False'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'MMSTIMESTAMP_DS2'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'TIM2'),
#                                           ('@EMS_Key',
#                                            'MARKET.SOLVER.SOLUTION.TIM2'),
#                                           ('@Grouping_ID', 'NEMMCO'),
#                                           ('@Can_Use_Last_Good', 'False'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'MMSTIMESTAMP_DS3'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'TIM3'),
#                                           ('@EMS_Key',
#                                            'MARKET.SOLVER.SOLUTION.TIM3'),
#                                           ('@Grouping_ID', 'NEMMCO'),
#                                           ('@Can_Use_Last_Good', 'False'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'MMSTIMESTAMP_DS4'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'TIM4'),
#                                           ('@EMS_Key',
#                                            'MARKET.SOLVER.SOLUTION.TIM4'),
#                                           ('@Grouping_ID', 'NEMMCO'),
#                                           ('@Can_Use_Last_Good', 'False'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'MVA_BW_WA'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'SMVA'),
#                                           ('@EMS_Key',
#                                            'B_WATER.LINE.WA_BW.SMVA'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'MVA_WA_BW'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'SMVA'),
#                                           ('@EMS_Key',
#                                            'WADAMANA.LINE.WA_BW.SMVA'),
#                                           ('@Grouping_ID', 'TAS1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'QLINE7113_T31BA_MVA'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'MVA'),
#                                           ('@EMS_Key',
#                                            'T31_BRAL.LINE.132KV_7113/1.MVA'),
#                                           ('@Grouping_ID', 'QLD1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')]),
#                              OrderedDict([('@SpdID', 'QLINE8866_S5WD_MVA'),
#                                           ('@Value', '0'),
#                                           ('@EMS_ID', 'MVA'),
#                                           ('@EMS_Key',
#                                            'S5_WESTD.LINE.275KV_8866.MVA'),
#                                           ('@Grouping_ID', 'QLD1'),
#                                           ('@Can_Use_Last_Good', 'True'),
#                                           ('@Can_Use_Value', 'False'),
#                                           ('@EMS_Good', 'False'),
#                                           ('@EMS_Replaced', 'False'),
#                                           ('@Data_Flags', '0'),
#                                           ('@Good_Input_Count', '0'),
#                                           ('@EMS_TimeStamp',
#                                            '1899-12-30T00:00:00+10:00'),
#                                           ('@Est_Value', '0'),
#                                           ('@Est_Flags', '0'),
#                                           ('@Can_Use_Est_Value', 'False'),
#                                           ('@IsReferenced', 'False')])])]))])

# %% [markdown]
# #### Generic Equation Collection
# Seems to only contain RHS elements for a given EquationID. Not sure if this is useful as will extract RHS for generic constraints from NEMDE Output. The way these terms are calculated also isn't completely clear. Documentation suggests non-linear operations used to construct RHS of generic constraints. Not sure what the difference between an equation and constraint is.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['GenericEquationCollection']['GenericEquation'][100]
# Out:
# OrderedDict([('@EquationID', 'X_DYN_LREG'),
#              ('@EffectiveDate', '2019-05-23T00:00:00+10:00'),
#              ('@VersionNo', '2'),
#              ('RHSTermCollection',
#               OrderedDict([('RHSTerm',
#                             [OrderedDict([('@TermID', '1'),
#                                           ('@Multiplier', '1'),
#                                           ('@SpdID', 'FCAS_TIME_ERROR_NSW'),
#                                           ('@SpdType', 'A'),
#                                           ('@Default', '1')]),
#                              OrderedDict([('@TermID', '2'),
#                                           ('@Multiplier', '1'),
#                                           ('@SpdID', 'FCAS_TIME_ERROR_QLD'),
#                                           ('@SpdType', 'A'),
#                                           ('@Default', '1')]),
#                              OrderedDict([('@TermID', '3'),
#                                           ('@Multiplier', '0.5'),
#                                           ('@Operation', 'PUSH'),
#                                           ('@SpdID', 'NOT_REQUIRED'),
#                                           ('@SpdType', 'C'),
#                                           ('@Default', '0')]),
#                              OrderedDict([('@TermID', '4'),
#                                           ('@Multiplier', '1'),
#                                           ('@Operation', 'MUL'),
#                                           ('@SpdID', 'NOT_REQUIRED'),
#                                           ('@SpdType', 'U'),
#                                           ('@Default', '0')]),
#                              OrderedDict([('@TermID', '5'),
#                                           ('@Multiplier', '1.5'),
#                                           ('@Operation', 'PUSH'),
#                                           ('@SpdID', 'TimeErrorThreshold'),
#                                           ('@SpdType', 'C'),
#                                           ('@Default', '1.5')]),
#                              OrderedDict([('@TermID', '6'),
#                                           ('@Multiplier', '1'),
#                                           ('@Operation', 'MAX'),
#                                           ('@SpdID', 'NOT_REQUIRED'),
#                                           ('@SpdType', 'U'),
#                                           ('@Default', '0')]),
#                              OrderedDict([('@TermID', '7'),
#                                           ('@Multiplier', '-1.5'),
#                                           ('@SpdID', 'TimeErrorOffset'),
#                                           ('@SpdType', 'C'),
#                                           ('@Default', '-1.5')]),
#                              OrderedDict([('@TermID', '8'),
#                                           ('@Multiplier', '60'),
#                                           ('@Operation', 'MUL'),
#                                           ('@SpdID', 'Calc_Increase'),
#                                           ('@SpdType', 'C'),
#                                           ('@Default', '0')]),
#                              OrderedDict([('@TermID', '9'),
#                                           ('@Multiplier', '1'),
#                                           ('@Operation', 'DUP'),
#                                           ('@SpdID', 'CheckLargerthanMin'),
#                                           ('@SpdType', 'U'),
#                                           ('@Default', '0')]),
#                              OrderedDict([('@TermID', '10'),
#                                           ('@Multiplier', '210'),
#                                           ('@Operation', 'STEP'),
#                                           ('@SpdID', 'LowerRegulation_Min'),
#                                           ('@SpdType', 'U'),
#                                           ('@Default', '210')]),
#                              OrderedDict([('@TermID', '11'),
#                                           ('@Multiplier', '1'),
#                                           ('@Operation', 'ADD'),
#                                           ('@SpdID', 'NOT_REQUIRED'),
#                                           ('@SpdType', 'U'),
#                                           ('@Default', '0')]),
#                              OrderedDict([('@TermID', '12'),
#                                           ('@Multiplier', '350'),
#                                           ('@Operation', 'PUSH'),
#                                           ('@SpdID', 'MaximumRegulation'),
#                                           ('@SpdType', 'C'),
#                                           ('@Default', '350')]),
#                              OrderedDict([('@TermID', '13'),
#                                           ('@Multiplier', '1'),
#                                           ('@Operation', 'MIN'),
#                                           ('@SpdID', 'CapRegulation'),
#                                           ('@SpdType', 'U'),
#                                           ('@Default', '0')])])]))])

# %% [markdown]
# #### Generic Constraint
# Contains constraint formulation information within NEMDE. Very important. RHS is a constant (will be extracted from output files), each record provides LHS variable information. E.g. the collection from which the factor is extracted, and the multiplier associated with the term. Will use this to generate constraints. Need to check each LHSFactorCollection, and determine an appropriate representation for the different constitutent components e.g. TraderFactor.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['GenericConstraintCollection']['GenericConstraint'][0:10]
# Out:
# [OrderedDict([('@ConstraintID', '#BNGSF2_E'),
#               ('@Version', '20190703000000_1'),
#               ('@EffectiveDate', '2019-07-03T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '20'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'BNGSF2')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '163069'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#BNGSF2_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#CHILDSF1_E'),
#               ('@Version', '20190903000000_1'),
#               ('@EffectiveDate', '2019-09-03T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '56'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'CHILDSF1')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '164698'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#CHILDSF1_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#CLERMSF1_E'),
#               ('@Version', '20190917000000_1'),
#               ('@EffectiveDate', '2019-09-17T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '37.5'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'CLERMSF1')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '165027'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#CLERMSF1_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#COOPGWF1_E'),
#               ('@Version', '20190911000000_1'),
#               ('@EffectiveDate', '2019-09-11T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '107'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'COOPGWF1')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '164910'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#COOPGWF1_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#CROWLWF1_E'),
#               ('@Version', '20190503000000_1'),
#               ('@EffectiveDate', '2019-05-03T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '72'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'CROWLWF1')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '161485'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#CROWLWF1_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#DAYDSF1_E'),
#               ('@Version', '20190614000000_1'),
#               ('@EffectiveDate', '2019-06-14T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '145'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'DAYDSF1')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '162561'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#DAYDSF1_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#DEVILS_G_E'),
#               ('@Version', '20190815000000_1'),
#               ('@EffectiveDate', '2019-08-15T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '64'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'DEVILS_G')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '164166'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#DEVILS_G_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#FINLYSF1_E'),
#               ('@Version', '20190925000000_2'),
#               ('@EffectiveDate', '2019-09-25T00:00:00+10:00'),
#               ('@VersionNo', '2'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '45'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'FINLYSF1')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '165250'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#FINLYSF1_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#HAUGHT11_E'),
#               ('@Version', '20190827000000_1'),
#               ('@EffectiveDate', '2019-08-27T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '100'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'HAUGHT11')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '164513'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#HAUGHT11_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))]),
#  OrderedDict([('@ConstraintID', '#HAYMSF1_E'),
#               ('@Version', '20190614000000_1'),
#               ('@EffectiveDate', '2019-06-14T00:00:00+10:00'),
#               ('@VersionNo', '1'),
#               ('@Type', 'LE'),
#               ('@ViolationPrice', '5292000'),
#               ('@RHS', '45'),
#               ('@Force_SCADA', 'False'),
#               ('LHSFactorCollection',
#                OrderedDict([('TraderFactor',
#                              OrderedDict([('@Factor', '1'),
#                                           ('@TradeType', 'ENOF'),
#                                           ('@TraderID', 'HAYMSF1')]))])),
#               ('s:ConstraintTrkCollection',
#                OrderedDict([('@xmlns:s',
#                              'http://www.w3.org/2001/XMLSchema-instance'),
#                             ('ConstraintTrkItem',
#                              OrderedDict([('@Invocation_ID', '162562'),
#                                           ('@Start_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@End_Interval_DateTime',
#                                            '2019-10-01T04:05:00+10:00'),
#                                           ('@DynamicRHS', '0'),
#                                           ('@GenConSetID', '#HAYMSF1_E'),
#                                           ('@Intervention', 'False'),
#                                           ('@ASConstraintType', 'NETWORK'),
#                                           ('@SystemNormal', 'False'),
#                                           ('@Invocation_Group_ID', '0'),
#                                           ('@LimitType', 'DEFAULT')]))]))])]

# %% [markdown]
# #### Period Collection
# Not sure what this is for. Seems to contain values used in model. Perhaps a convenient data structure to quickly inspect NEMDE inputs?

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['PeriodCollection']['Period'].keys()
# Out:
# odict_keys(['@PeriodID', 'EnteredValuePeriodCollection', 'RegionPeriodCollection', 'TraderPeriodCollection', 'InterconnectorPeriodCollection', 'GenericConstraintPeriodCollection', 'Non_Scheduled_Generator_Collection'])

# %% [markdown]
# Not sure what these values are for.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['PeriodCollection']['Period']['EnteredValuePeriodCollection']['EnteredValuePeriod'][:4]
# Out:
# [OrderedDict([('@SpdID', '$BLOWERNG'), ('@Value', '20')]),
#  OrderedDict([('@SpdID', '$STAN-1'), ('@Value', '220')]),
#  OrderedDict([('@SpdID', 'DATA_MMS_ALERT1'), ('@Value', '274')]),
#  OrderedDict([('@SpdID', 'NRAT15_ARTW85'), ('@Value', '1071')])]

# %% [markdown]
# Perhaps this is forecast energy price (or actual energy price). Also seems to contain demand forecast for the interval. DF may be difference between forecast demand and actual demand. So it's possible these are realised prices, and the forecast is the value that was predicted prior to the interval.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['PeriodCollection']['Period']['RegionPeriodCollection']['RegionPeriod'][:2]
# Out:
# [OrderedDict([('@RegionID', 'NSW1'),
#               ('@DF', '-9.365234375'),
#               ('@DemandForecast', '6264.6259765625'),
#               ('@Suspension_Schedule_Energy_Price', '57.45'),
#               ('@Suspension_Schedule_R6_Price', '2.45'),
#               ('@Suspension_Schedule_R60_Price', '1.65'),
#               ('@Suspension_Schedule_R5_Price', '0.85'),
#               ('@Suspension_Schedule_RReg_Price', '29.54'),
#               ('@Suspension_Schedule_L6_Price', '0.25'),
#               ('@Suspension_Schedule_L60_Price', '0.2'),
#               ('@Suspension_Schedule_L5_Price', '0.45'),
#               ('@Suspension_Schedule_LReg_Price', '27.62')]),
#  OrderedDict([('@RegionID', 'QLD1'),
#               ('@DF', '18.6572265625'),
#               ('@DemandForecast', '5172.32861328125'),
#               ('@Suspension_Schedule_Energy_Price', '47.11'),
#               ('@Suspension_Schedule_R6_Price', '2.45'),
#               ('@Suspension_Schedule_R60_Price', '1.65'),
#               ('@Suspension_Schedule_R5_Price', '0.85'),
#               ('@Suspension_Schedule_RReg_Price', '29.54'),
#               ('@Suspension_Schedule_L6_Price', '0.25'),
#               ('@Suspension_Schedule_L60_Price', '0.2'),
#               ('@Suspension_Schedule_L5_Price', '0.45'),
#               ('@Suspension_Schedule_LReg_Price', '27.62')])]

# %% [markdown]
# Contains quantity bands for each generator, and also max available.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['PeriodCollection']['Period']['TraderPeriodCollection']['TraderPeriod'][:2]
# Out:
# [OrderedDict([('@TraderID', 'AGLHAL'),
#               ('@RegionID', 'SA1'),
#               ('@TradePriceStructureID', '20191001001'),
#               ('TradeCollection',
#                OrderedDict([('Trade',
#                              OrderedDict([('@TradeType', 'ENOF'),
#                                           ('@RampUpRate', '720'),
#                                           ('@RampDnRate', '720'),
#                                           ('@MaxAvail', '181'),
#                                           ('@BandAvail1', '0'),
#                                           ('@BandAvail2', '0'),
#                                           ('@BandAvail3', '0'),
#                                           ('@BandAvail4', '0'),
#                                           ('@BandAvail5', '0'),
#                                           ('@BandAvail6', '0'),
#                                           ('@BandAvail7', '60'),
#                                           ('@BandAvail8', '0'),
#                                           ('@BandAvail9', '0'),
#                                           ('@BandAvail10', '160')]))]))]),
#  OrderedDict([('@TraderID', 'AGLSOM'),
#               ('@RegionID', 'VIC1'),
#               ('@TradePriceStructureID', '20191001001'),
#               ('TradeCollection',
#                OrderedDict([('Trade',
#                              OrderedDict([('@TradeType', 'ENOF'),
#                                           ('@RampUpRate', '360'),
#                                           ('@RampDnRate', '360'),
#                                           ('@MaxAvail', '40'),
#                                           ('@BandAvail1', '0'),
#                                           ('@BandAvail2', '0'),
#                                           ('@BandAvail3', '0'),
#                                           ('@BandAvail4', '0'),
#                                           ('@BandAvail5', '0'),
#                                           ('@BandAvail6', '0'),
#                                           ('@BandAvail7', '170'),
#                                           ('@BandAvail8', '0'),
#                                           ('@BandAvail9', '0'),
#                                           ('@BandAvail10', '0')]))]))])]

# %% [markdown]
# Interconector information
#
# **Note:** Some interconnectors submit offers to the market. Must take this into account when formulating objective and constraints associated with interconnector capacity.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['PeriodCollection']['Period']['InterconnectorPeriodCollection']['InterconnectorPeriod'][:5]
# Out:
# [OrderedDict([('@InterconnectorID', 'N-Q-MNSP1'),
#               ('@MNSP', '0'),
#               ('@LossModelID', '637054995000000000'),
#               ('@FromRegion', 'NSW1'),
#               ('@ToRegion', 'QLD1'),
#               ('@LowerLimit', '264'),
#               ('@UpperLimit', '264'),
#               ('@LossDemandConstant', '0')]),
#  OrderedDict([('@InterconnectorID', 'NSW1-QLD1'),
#               ('@MNSP', '0'),
#               ('@LossModelID', '637054995000000000'),
#               ('@FromRegion', 'NSW1'),
#               ('@ToRegion', 'QLD1'),
#               ('@LowerLimit', '1659'),
#               ('@UpperLimit', '1229'),
#               ('@LossDemandConstant', '0.0497491031460742')]),
#  OrderedDict([('@InterconnectorID', 'T-V-MNSP1'),
#               ('@MNSP', '1'),
#               ('@MNSPPriceStructureID', '20191001'),
#               ('@LossModelID', '637054995000000000'),
#               ('@FromRegion', 'TAS1'),
#               ('@ToRegion', 'VIC1'),
#               ('@LowerLimit', '478'),
#               ('@UpperLimit', '594'),
#               ('@FromRegionLF', '1'),
#               ('@ToRegionLF', '0.9728'),
#               ('@FromRegionLFImport', '1'),
#               ('@FromRegionLFExport', '1'),
#               ('@ToRegionLFImport', '0.9728'),
#               ('@ToRegionLFExport', '0.9789'),
#               ('@LossDemandConstant', '0'),
#               ('MNSPOfferCollection',
#                OrderedDict([('MNSPOffer',
#                              [OrderedDict([('@RegionID', 'TAS1'),
#                                            ('@MaxAvail', '478'),
#                                            ('@RampUpRate', '12000'),
#                                            ('@RampDnRate', '12000'),
#                                            ('@BandAvail1', '0'),
#                                            ('@BandAvail2', '0'),
#                                            ('@BandAvail3', '0'),
#                                            ('@BandAvail4', '478'),
#                                            ('@BandAvail5', '0'),
#                                            ('@BandAvail6', '0'),
#                                            ('@BandAvail7', '0'),
#                                            ('@BandAvail8', '0'),
#                                            ('@BandAvail9', '0'),
#                                            ('@BandAvail10', '0')]),
#                               OrderedDict([('@RegionID', 'VIC1'),
#                                            ('@MaxAvail', '478'),
#                                            ('@RampUpRate', '12000'),
#                                            ('@RampDnRate', '12000'),
#                                            ('@BandAvail1', '0'),
#                                            ('@BandAvail2', '0'),
#                                            ('@BandAvail3', '0'),
#                                            ('@BandAvail4', '594'),
#                                            ('@BandAvail5', '0'),
#                                            ('@BandAvail6', '0'),
#                                            ('@BandAvail7', '0'),
#                                            ('@BandAvail8', '0'),
#                                            ('@BandAvail9', '0'),
#                                            ('@BandAvail10', '0')])])]))]),
#  OrderedDict([('@InterconnectorID', 'V-S-MNSP1'),
#               ('@MNSP', '0'),
#               ('@LossModelID', '637054995000000000'),
#               ('@FromRegion', 'VIC1'),
#               ('@ToRegion', 'SA1'),
#               ('@LowerLimit', '270'),
#               ('@UpperLimit', '270'),
#               ('@LossDemandConstant', '0')]),
#  OrderedDict([('@InterconnectorID', 'V-SA'),
#               ('@MNSP', '0'),
#               ('@LossModelID', '637054995000000000'),
#               ('@FromRegion', 'VIC1'),
#               ('@ToRegion', 'SA1'),
#               ('@LowerLimit', '850'),
#               ('@UpperLimit', '950'),
#               ('@LossDemandConstant', '-0.00899878434640827')])]

# %% [markdown]
# Seems to provide some high-level assessment as to whether intervention used or not. Contains associated constraint ID. Not sure if very useful.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['PeriodCollection']['Period']['GenericConstraintPeriodCollection']['GenericConstraintPeriod'][-100:]
# Out:
# [OrderedDict([('@ConstraintID', 'V:SS_870_HY_TEST'),
#               ('@Version', '20180807000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:SS_870_HY_TEST_DYN'),
#               ('@Version', '20161121000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:SS_920'),
#               ('@Version', '20180807000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:S_460_OSC_AUTO'),
#               ('@Version', '20160630000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:S_570_1'),
#               ('@Version', '20160816000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:S_570_OSC_AUTO'),
#               ('@Version', '20160630000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:S_600_HY_TEST'),
#               ('@Version', '20180807000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:S_600_HY_TEST_DYN'),
#               ('@Version', '20161121000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:S_650_HY_TEST'),
#               ('@Version', '20180807000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:S_650_HY_TEST_DYN'),
#               ('@Version', '20161121000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:S_700'),
#               ('@Version', '20180807000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V:T_NIL_BL_1'),
#               ('@Version', '20130821000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>N-NIL_HA'),
#               ('@Version', '20190715000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>N-NIL_HB'),
#               ('@Version', '20190715000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>N-NIL_HG'),
#               ('@Version', '20190715000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>N-NIL_HH'),
#               ('@Version', '20190715000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NIL_5'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NIL_6'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NIL_7A'),
#               ('@Version', '20190708000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NIL_7B'),
#               ('@Version', '20190708000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NIL_7C'),
#               ('@Version', '20190708000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NIL_8'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NIL_8_5M'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NSWRB_11'),
#               ('@Version', '20190902000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>SML_NSWRB_11_1'),
#               ('@Version', '20190913000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>S_NIL_DVBG_DVBR'),
#               ('@Version', '20190614000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL1A_R'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_1A'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_1B'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_2A_R'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_2B_R'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_3'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_4A'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_4B'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_4C'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_5'),
#               ('@Version', '20190708000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_6'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_6A_R'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_6B_R'),
#               ('@Version', '20190708000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>>V_NIL_9'),
#               ('@Version', '20190920000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>SML_NSWRB_10'),
#               ('@Version', '20190902000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>SML_NSWRB_10_1'),
#               ('@Version', '20190913000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>SML_NSWRB_9'),
#               ('@Version', '20190902000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>SML_NSWRB_9_1'),
#               ('@Version', '20190913000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>S_NIL_HYSE'),
#               ('@Version', '20150702000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>S_NIL_SETX_SETX'),
#               ('@Version', '20190314000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_13'),
#               ('@Version', '20190111000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_14'),
#               ('@Version', '20190111000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_15'),
#               ('@Version', '20190627000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_16'),
#               ('@Version', '20190111000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_17'),
#               ('@Version', '20190228000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_18'),
#               ('@Version', '20190503000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_6'),
#               ('@Version', '20190423000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_7'),
#               ('@Version', '20190129000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_9'),
#               ('@Version', '20190305000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_RADIAL_10'),
#               ('@Version', '20190626000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V>V_NIL_RADIAL_11'),
#               ('@Version', '20190111000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'VSML_220'),
#               ('@Version', '20120704000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'VSML_ROC_80'),
#               ('@Version', '20160823000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'VSML_VFRB_OFF'),
#               ('@Version', '20130821000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'VTBL_ROC'),
#               ('@Version', '20140115000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^SML_NSWRB_2'),
#               ('@Version', '20180806000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^S_HYCP'),
#               ('@Version', '20190920000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^N_NIL_1'),
#               ('@Version', '20190515000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^SML_NIL_3'),
#               ('@Version', '20190708000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MAXG_1'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MAXG_2'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MAXG_3'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MAXG_SECP_1'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MAXG_SECP_2'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MG_PP_2-DS'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MG_PP_CP_2'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MG_PP_N-2_1'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_MG_PP_N-2_3'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_SETB_SECP_1'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_SETB_SECP_2'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_TBSE_1'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V^^S_NIL_TBSE_2'),
#               ('@Version', '20190805000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_ARWF_FSTTRP_5'),
#               ('@Version', '20190503000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_BANNERTSF_FLT_44'),
#               ('@Version', '20190905000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_BANSF_20INV'),
#               ('@Version', '20190905000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_BANSF_BBD_60'),
#               ('@Version', '20190816000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_BANSF_BBD_80'),
#               ('@Version', '20190816000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_CWWF_GFT_5'),
#               ('@Version', '20190503000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_GANNSF_11INV'),
#               ('@Version', '20190905000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_GANWRSF_FLT_25'),
#               ('@Version', '20190904000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_GANWR_SF_BAT_50'),
#               ('@Version', '20190124000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_KARADSF_FLT_45'),
#               ('@Version', '20190719000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_KARSF_19INV'),
#               ('@Version', '20190905000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_MORTLAKE1_ZERO'),
#               ('@Version', '20130821000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_MTGBRAND_44WT'),
#               ('@Version', '20190129000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_MWWF_GFT_5'),
#               ('@Version', '20190508000000_2'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_OAKHILL_TFB_42'),
#               ('@Version', '20170418000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_OWF_NRB_0'),
#               ('@Version', '20180620000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_OWF_TGTSNRBHTN_30'),
#               ('@Version', '20170505000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_S_NIL_ROCOF'),
#               ('@Version', '20190103000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_T_NIL_BL1'),
#               ('@Version', '20141111000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_T_NIL_FCSPS'),
#               ('@Version', '20161220000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_WEMENSF_19INV'),
#               ('@Version', '20190905000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')]),
#  OrderedDict([('@ConstraintID', 'V_WEMENSF_FLT_44'),
#               ('@Version', '20190905000000_1'),
#               ('@Intervention', '0'),
#               ('@Category', '1')])]

# %% [markdown]
# Could be the output of all non-scheduled generators.

# %%
doc['NEMSPDCaseFile']['NemSpdInputs']['PeriodCollection']['Period']['Non_Scheduled_Generator_Collection']['Non_Scheduled_Generator']
# Out:
# [OrderedDict([('@DUID', 'BARCSF1'), ('@MW', '0.800000011920929')]),
#  OrderedDict([('@DUID', 'BUTLERSG'), ('@MW', '9.89999866485596')]),
#  OrderedDict([('@DUID', 'CALL_A_4'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'CAPTL_WF'), ('@MW', '15.6000061035156')]),
#  OrderedDict([('@DUID', 'CATHROCK'), ('@MW', '40.439998626709')]),
#  OrderedDict([('@DUID', 'CHALLHWF'), ('@MW', '3.09999990463257')]),
#  OrderedDict([('@DUID', 'CLOVER'), ('@MW', '-0.00999999977648258')]),
#  OrderedDict([('@DUID', 'CLUNY'), ('@MW', '13.220874786377')]),
#  OrderedDict([('@DUID', 'CNUNDAWF'), ('@MW', '5.8067741394043')]),
#  OrderedDict([('@DUID', 'CULLRGWF'), ('@MW', '14.6400003433228')]),
#  OrderedDict([('@DUID', 'ERGT01'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'GB01'), ('@MW', '0.00919342041015625')]),
#  OrderedDict([('@DUID', 'GERMCRK'), ('@MW', '34.9000015258789')]),
#  OrderedDict([('@DUID', 'GRIFSF1'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'HUGSF1'), ('@MW', '-0.255000025033951')]),
#  OrderedDict([('@DUID', 'LKBONNY1'), ('@MW', '11.7888355255127')]),
#  OrderedDict([('@DUID', 'LRSF1'), ('@MW', '-0.0190000012516975')]),
#  OrderedDict([('@DUID', 'MBAHNTH'), ('@MW', '53.4375')]),
#  OrderedDict([('@DUID', 'MLSP1'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'MLWF1'), ('@MW', '6.22500038146973')]),
#  OrderedDict([('@DUID', 'MTMILLAR'), ('@MW', '40.510498046875')]),
#  OrderedDict([('@DUID', 'PALOONA'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'PIONEER'), ('@MW', '40.5')]),
#  OrderedDict([('@DUID', 'PORTWF'), ('@MW', '22.6000003814697')]),
#  OrderedDict([('@DUID', 'REPULSE'), ('@MW', '24.1171894073486')]),
#  OrderedDict([('@DUID', 'ROWALLAN'), ('@MW', '9.38619995117187')]),
#  OrderedDict([('@DUID', 'ROYALLA1'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'RPCG'), ('@MW', '9.30000019073486')]),
#  OrderedDict([('@DUID', 'RUBICON'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'SATGN1'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'SATGS1'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'STARHLWF'), ('@MW', '17.5948696136475')]),
#  OrderedDict([('@DUID', 'WAUBRAWF'), ('@MW', '0')]),
#  OrderedDict([('@DUID', 'WOOLNTH1'), ('@MW', '0.890015244483948')]),
#  OrderedDict([('@DUID', 'WPWF'), ('@MW', '17')]),
#  OrderedDict([('@DUID', 'YAMBUKWF'), ('@MW', '3.59999990463257')]),
#  OrderedDict([('@DUID', 'YSWF1'), ('@MW', '2.79999995231628')])]

# %% [markdown]
# ## Outputs

# %%
doc['NEMSPDCaseFile']['NemSpdOutputs'].keys()
# Out:
# odict_keys(['CaseSolution', 'PeriodSolution', 'RegionSolution', 'InterconnectorSolution', 'TraderSolution', 'ConstraintSolution'])

# %% [markdown]
# #### Case solution
# Constains total objective value. Useful to check if own formulation matches that of actual NEMDE program.

# %%
doc['NEMSPDCaseFile']['NemSpdOutputs']['CaseSolution']
# Out:
# OrderedDict([('@SolverStatus', '1'),
#              ('@Terminal', 'NORREWMDS1A'),
#              ('@InterventionStatus', '1'),
#              ('@SolverVersion', '3.3.15'),
#              ('@NPLStatus', '0'),
#              ('@TotalObjective', '35998147.07'),
#              ('@TotalAreaGenViolation', '0'),
#              ('@TotalInterconnectorViolation', '0'),
#              ('@TotalGenericViolation', '40'),
#              ('@TotalRampRateViolation', '0'),
#              ('@TotalUnitMWCapacityViolation', '17.61'),
#              ('@TotalEnergyConstrViolation', '0'),
#              ('@TotalEnergyOfferViolation', '0'),
#              ('@TotalASProfileViolation', '0'),
#              ('@TotalFastStartViolation', '0'),
#              ('@NumberOfDegenerateLPsSolved', '0'),
#              ('@TotalUIGFViolation', '0'),
#              ('@OCD_Status', 'Not_OCD')])

# %% [markdown]
# #### Period Solution
# Also contains objective value. Can check objective value with and without intervention. Not sure what the difference between CaseSolution and PeriodSolution is though.

# %%
doc['NEMSPDCaseFile']['NemSpdOutputs']['PeriodSolution']
# Out:
# [OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@SwitchRunBestStatus', '1'),
#               ('@TotalObjective', '76883050.27806'),
#               ('@SolverStatus', '1'),
#               ('@NPLStatus', '0'),
#               ('@TotalAreaGenViolation', '0'),
#               ('@TotalInterconnectorViolation', '0'),
#               ('@TotalGenericViolation', '0'),
#               ('@TotalRampRateViolation', '0'),
#               ('@TotalUnitMWCapacityViolation', '16.61'),
#               ('@TotalEnergyConstrViolation', '0'),
#               ('@TotalEnergyOfferViolation', '0'),
#               ('@TotalASProfileViolation', '0'),
#               ('@TotalFastStartViolation', '0'),
#               ('@TotalMNSPRampRateViolation', '0'),
#               ('@TotalMNSPOfferViolation', '0'),
#               ('@TotalMNSPCapacityViolation', '0'),
#               ('@TotalUIGFViolation', '0')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@SwitchRunBestStatus', '1'),
#               ('@TotalObjective', '8997697.57229'),
#               ('@SolverStatus', '1'),
#               ('@NPLStatus', '0'),
#               ('@TotalAreaGenViolation', '0'),
#               ('@TotalInterconnectorViolation', '0'),
#               ('@TotalGenericViolation', '40'),
#               ('@TotalRampRateViolation', '0'),
#               ('@TotalUnitMWCapacityViolation', '1'),
#               ('@TotalEnergyConstrViolation', '0'),
#               ('@TotalEnergyOfferViolation', '0'),
#               ('@TotalASProfileViolation', '0'),
#               ('@TotalFastStartViolation', '0'),
#               ('@TotalMNSPRampRateViolation', '0'),
#               ('@TotalMNSPOfferViolation', '0'),
#               ('@TotalMNSPCapacityViolation', '0'),
#               ('@TotalUIGFViolation', '0')])]

# %% [markdown]
# #### RegionSolution
# Contains region prices. Useful when comparing model outputs with actual NEMDE solution.

# %%
doc['NEMSPDCaseFile']['NemSpdOutputs']['RegionSolution']
# Out:
# [OrderedDict([('@RegionID', 'NSW1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyPrice', '82.21926'),
#               ('@DispatchedGeneration', '5214.87'),
#               ('@DispatchedLoad', '0'),
#               ('@FixedDemand', '6220.62'),
#               ('@NetExport', '-1005.75'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '98'),
#               ('@R60Dispatch', '60.38'),
#               ('@R5Dispatch', '72'),
#               ('@R5RegDispatch', '78.95'),
#               ('@L6Dispatch', '30'),
#               ('@L60Dispatch', '30'),
#               ('@L5Dispatch', '15'),
#               ('@L5RegDispatch', '65.95'),
#               ('@R6Price', '2.29'),
#               ('@R60Price', '1'),
#               ('@R5Price', '0.73'),
#               ('@R5RegPrice', '14.73'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14.73'),
#               ('@AvailableGeneration', '8395'),
#               ('@AvailableLoad', '0'),
#               ('@ClearedDemand', '6265.38')]),
#  OrderedDict([('@RegionID', 'QLD1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyPrice', '63.73003'),
#               ('@DispatchedGeneration', '6130.25'),
#               ('@DispatchedLoad', '0'),
#               ('@FixedDemand', '5137.33'),
#               ('@NetExport', '992.92'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '49.83'),
#               ('@R60Dispatch', '69.8'),
#               ('@R5Dispatch', '27.13'),
#               ('@R5RegDispatch', '30.92'),
#               ('@L6Dispatch', '0'),
#               ('@L60Dispatch', '0'),
#               ('@L5Dispatch', '0'),
#               ('@L5RegDispatch', '48.05'),
#               ('@R6Price', '2.29'),
#               ('@R60Price', '1'),
#               ('@R5Price', '0.73'),
#               ('@R5RegPrice', '14.73'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14.73'),
#               ('@AvailableGeneration', '9984'),
#               ('@AvailableLoad', '0'),
#               ('@ClearedDemand', '5173.01')]),
#  OrderedDict([('@RegionID', 'SA1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyPrice', '70.3602'),
#               ('@DispatchedGeneration', '1633.21'),
#               ('@DispatchedLoad', '0'),
#               ('@FixedDemand', '1097.78'),
#               ('@NetExport', '535.43'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '106.15'),
#               ('@R60Dispatch', '49.15'),
#               ('@R5Dispatch', '71'),
#               ('@R5RegDispatch', '50'),
#               ('@L6Dispatch', '52'),
#               ('@L60Dispatch', '25'),
#               ('@L5Dispatch', '42'),
#               ('@L5RegDispatch', '44'),
#               ('@R6Price', '2.29'),
#               ('@R60Price', '1'),
#               ('@R5Price', '0.73'),
#               ('@R5RegPrice', '14.73'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14.73'),
#               ('@AvailableGeneration', '1880'),
#               ('@AvailableLoad', '80'),
#               ('@ClearedDemand', '1107.98')]),
#  OrderedDict([('@RegionID', 'TAS1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyPrice', '83.83134'),
#               ('@DispatchedGeneration', '756.92'),
#               ('@DispatchedLoad', '0'),
#               ('@FixedDemand', '978.43'),
#               ('@NetExport', '-221.51'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '62.18'),
#               ('@R60Dispatch', '130.19'),
#               ('@R5Dispatch', '118.41'),
#               ('@R5RegDispatch', '50'),
#               ('@L6Dispatch', '48.4'),
#               ('@L60Dispatch', '70.47'),
#               ('@L5Dispatch', '47.82'),
#               ('@L5RegDispatch', '50'),
#               ('@R6Price', '10'),
#               ('@R60Price', '0.49'),
#               ('@R5Price', '0.7'),
#               ('@R5RegPrice', '14.5'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14'),
#               ('@AvailableGeneration', '1863'),
#               ('@AvailableLoad', '0'),
#               ('@ClearedDemand', '978.43')]),
#  OrderedDict([('@RegionID', 'VIC1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyPrice', '81.99132'),
#               ('@DispatchedGeneration', '4141.44'),
#               ('@DispatchedLoad', '10'),
#               ('@FixedDemand', '4313.23'),
#               ('@NetExport', '-181.79'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '54.23'),
#               ('@R60Dispatch', '60.88'),
#               ('@R5Dispatch', '52.88'),
#               ('@R5RegDispatch', '10.13'),
#               ('@L6Dispatch', '10'),
#               ('@L60Dispatch', '118.33'),
#               ('@L5Dispatch', '120'),
#               ('@L5RegDispatch', '2'),
#               ('@R6Price', '2.29'),
#               ('@R60Price', '1'),
#               ('@R5Price', '0.73'),
#               ('@R5RegPrice', '14.73'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14.73'),
#               ('@AvailableGeneration', '7021'),
#               ('@AvailableLoad', '10'),
#               ('@ClearedDemand', '4351.89')]),
#  OrderedDict([('@RegionID', 'NSW1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@EnergyPrice', '82.21926'),
#               ('@DispatchedGeneration', '5188.88'),
#               ('@DispatchedLoad', '0'),
#               ('@FixedDemand', '6220.62'),
#               ('@NetExport', '-1031.74'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '97.86'),
#               ('@R60Dispatch', '63.98'),
#               ('@R5Dispatch', '72'),
#               ('@R5RegDispatch', '69.16'),
#               ('@L6Dispatch', '25'),
#               ('@L60Dispatch', '25'),
#               ('@L5Dispatch', '15'),
#               ('@L5RegDispatch', '65.95'),
#               ('@R6Price', '2'),
#               ('@R60Price', '1'),
#               ('@R5Price', '0.73'),
#               ('@R5RegPrice', '20'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14.73'),
#               ('@AvailableGeneration', '8395'),
#               ('@AvailableLoad', '0'),
#               ('@ClearedDemand', '6264.84')]),
#  OrderedDict([('@RegionID', 'QLD1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@EnergyPrice', '63.73003'),
#               ('@DispatchedGeneration', '6124.66'),
#               ('@DispatchedLoad', '0'),
#               ('@FixedDemand', '5137.33'),
#               ('@NetExport', '987.33'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '49.83'),
#               ('@R60Dispatch', '69.8'),
#               ('@R5Dispatch', '30.73'),
#               ('@R5RegDispatch', '50.84'),
#               ('@L6Dispatch', '0'),
#               ('@L60Dispatch', '0'),
#               ('@L5Dispatch', '0'),
#               ('@L5RegDispatch', '48.05'),
#               ('@R6Price', '2'),
#               ('@R60Price', '1'),
#               ('@R5Price', '0.73'),
#               ('@R5RegPrice', '20'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14.73'),
#               ('@AvailableGeneration', '9984'),
#               ('@AvailableLoad', '0'),
#               ('@ClearedDemand', '5172.44')]),
#  OrderedDict([('@RegionID', 'SA1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@EnergyPrice', '71.21494'),
#               ('@DispatchedGeneration', '1673.21'),
#               ('@DispatchedLoad', '0'),
#               ('@FixedDemand', '1097.78'),
#               ('@NetExport', '575.43'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '106.15'),
#               ('@R60Dispatch', '49.15'),
#               ('@R5Dispatch', '71'),
#               ('@R5RegDispatch', '50'),
#               ('@L6Dispatch', '52'),
#               ('@L60Dispatch', '25'),
#               ('@L5Dispatch', '42'),
#               ('@L5RegDispatch', '44'),
#               ('@R6Price', '2'),
#               ('@R60Price', '1'),
#               ('@R5Price', '0.73'),
#               ('@R5RegPrice', '20'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14.73'),
#               ('@AvailableGeneration', '1880'),
#               ('@AvailableLoad', '80'),
#               ('@ClearedDemand', '1111.38')]),
#  OrderedDict([('@RegionID', 'TAS1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@EnergyPrice', '82.94404'),
#               ('@DispatchedGeneration', '761.02'),
#               ('@DispatchedLoad', '0'),
#               ('@FixedDemand', '978.43'),
#               ('@NetExport', '-217.41'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '62.18'),
#               ('@R60Dispatch', '126.09'),
#               ('@R5Dispatch', '114.31'),
#               ('@R5RegDispatch', '50'),
#               ('@L6Dispatch', '53.4'),
#               ('@L60Dispatch', '70.47'),
#               ('@L5Dispatch', '47.08'),
#               ('@L5RegDispatch', '50'),
#               ('@R6Price', '10'),
#               ('@R60Price', '0.49'),
#               ('@R5Price', '0.7'),
#               ('@R5RegPrice', '14.5'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14'),
#               ('@AvailableGeneration', '1863'),
#               ('@AvailableLoad', '0'),
#               ('@ClearedDemand', '978.43')]),
#  OrderedDict([('@RegionID', 'VIC1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@EnergyPrice', '81.33813'),
#               ('@DispatchedGeneration', '4140.44'),
#               ('@DispatchedLoad', '10'),
#               ('@FixedDemand', '4313.23'),
#               ('@NetExport', '-182.79'),
#               ('@SurplusGeneration', '0'),
#               ('@R6Dispatch', '54'),
#               ('@R60Dispatch', '61'),
#               ('@R5Dispatch', '53'),
#               ('@R5RegDispatch', '0'),
#               ('@L6Dispatch', '10'),
#               ('@L60Dispatch', '123.33'),
#               ('@L5Dispatch', '120.74'),
#               ('@L5RegDispatch', '2'),
#               ('@R6Price', '2'),
#               ('@R60Price', '1'),
#               ('@R5Price', '0.73'),
#               ('@R5RegPrice', '20'),
#               ('@L6Price', '0.04'),
#               ('@L60Price', '0.19'),
#               ('@L5Price', '0.44'),
#               ('@L5RegPrice', '14.73'),
#               ('@AvailableGeneration', '7021'),
#               ('@AvailableLoad', '10'),
#               ('@ClearedDemand', '4361.13')])]

# %% [markdown]
# #### Interconnector Solution
# Gives interconnector flow values.

# %%
doc['NEMSPDCaseFile']['NemSpdOutputs']['InterconnectorSolution']
# Out:
# [OrderedDict([('@InterconnectorID', 'N-Q-MNSP1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@Flow', '-112.71329'),
#               ('@Losses', '12.81813'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '12.81813'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '0.775123')]),
#  OrderedDict([('@InterconnectorID', 'NSW1-QLD1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@Flow', '-844.52365'),
#               ('@Losses', '67.70421'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '67.70421'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '0.845079')]),
#  OrderedDict([('@InterconnectorID', 'T-V-MNSP1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@Flow', '-221.50667'),
#               ('@Losses', '5.96831'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '5.96831'),
#               ('@NPLExists', '0'),
#               ('@RampPrice', '0.000000'),
#               ('@RampDeficit', '0.000000'),
#               ('@InterRegionalLossFactor', '0.951286')]),
#  OrderedDict([('@InterconnectorID', 'V-S-MNSP1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@Flow', '-25.23291'),
#               ('@Losses', '3.28176'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '3.28176'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '0.858142')]),
#  OrderedDict([('@InterconnectorID', 'V-SA'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@Flow', '-500'),
#               ('@Losses', '34.50189'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '34.50189'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '0.863178')]),
#  OrderedDict([('@InterconnectorID', 'VIC1-NSW1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@Flow', '93.27075'),
#               ('@Losses', '-0.16518'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '-0.16518'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '1.002780')]),
#  OrderedDict([('@InterconnectorID', 'N-Q-MNSP1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@Flow', '-107.69962'),
#               ('@Losses', '11.56059'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '11.56059'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '0.775123')]),
#  OrderedDict([('@InterconnectorID', 'NSW1-QLD1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@Flow', '-844.52365'),
#               ('@Losses', '67.70421'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '67.70421'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '0.845079')]),
#  OrderedDict([('@InterconnectorID', 'T-V-MNSP1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@Flow', '-217.40667'),
#               ('@Losses', '5.76807'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '5.76807'),
#               ('@NPLExists', '0'),
#               ('@RampPrice', '0.000000'),
#               ('@RampDeficit', '0.000000'),
#               ('@InterRegionalLossFactor', '0.953738')]),
#  OrderedDict([('@InterconnectorID', 'V-S-MNSP1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@Flow', '-108.2564'),
#               ('@Losses', '22.17455'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '22.17455'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '0.713450')]),
#  OrderedDict([('@InterconnectorID', 'V-SA'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@Flow', '-453.57927'),
#               ('@Losses', '28.19144'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '28.19144'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '0.875542')]),
#  OrderedDict([('@InterconnectorID', 'VIC1-NSW1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '1'),
#               ('@Flow', '123.7367'),
#               ('@Losses', '0.13338'),
#               ('@Deficit', '0'),
#               ('@Price', '0'),
#               ('@IdealLosses', '0.13338'),
#               ('@NPLExists', '0'),
#               ('@InterRegionalLossFactor', '1.010833')])]

# %% [markdown]
# #### Trader Solution
# Not sure what this is supposed to show. Just gives prices. Note that intervation flag is included, so this should always be considered when generating model (otherwise duplicate records will exist).

# %%
doc['NEMSPDCaseFile']['NemSpdOutputs']['TraderSolution'][:10]
# Out:
# [OrderedDict([('@TraderID', 'AGLHAL'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '0'),
#               ('@R60Target', '0'),
#               ('@R5Target', '0'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '0'),
#               ('@R60Price', '0'),
#               ('@R5Price', '0'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '0'),
#               ('@L5Price', '0'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@FSTargetMode', '0'),
#               ('@RampUpRate', '720'),
#               ('@RampDnRate', '720'),
#               ('@RampPrice', '0'),
#               ('@RampDeficit', '0')]),
#  OrderedDict([('@TraderID', 'AGLSOM'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '0'),
#               ('@R60Target', '0'),
#               ('@R5Target', '0'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '0'),
#               ('@R60Price', '0'),
#               ('@R5Price', '0'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '0'),
#               ('@L5Price', '0'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@FSTargetMode', '0'),
#               ('@RampUpRate', '360'),
#               ('@RampDnRate', '360'),
#               ('@RampPrice', '0'),
#               ('@RampDeficit', '0')]),
#  OrderedDict([('@TraderID', 'ANGAST1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '0'),
#               ('@R60Target', '0'),
#               ('@R5Target', '0'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '0'),
#               ('@R60Price', '0'),
#               ('@R5Price', '0'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '0'),
#               ('@L5Price', '0'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@RampUpRate', '840'),
#               ('@RampDnRate', '840'),
#               ('@RampPrice', '0'),
#               ('@RampDeficit', '0')]),
#  OrderedDict([('@TraderID', 'APD01'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '16.35903'),
#               ('@R60Target', '30'),
#               ('@R5Target', '30'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '-1029000'),
#               ('@R60Price', '-1029000'),
#               ('@R5Price', '-1029000'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '-2278500'),
#               ('@L60Price', '-2278500'),
#               ('@L5Price', '-2278500'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@R6Flags', '1'),
#               ('@R60Flags', '1'),
#               ('@R5Flags', '1'),
#               ('@L6Flags', '0'),
#               ('@L60Flags', '0'),
#               ('@L5Flags', '0')]),
#  OrderedDict([('@TraderID', 'ARWF1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0.029'),
#               ('@R6Target', '0'),
#               ('@R60Target', '0'),
#               ('@R5Target', '0'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '0'),
#               ('@R60Price', '0'),
#               ('@R5Price', '0'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '0'),
#               ('@L5Price', '0'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@RampUpRate', '1200'),
#               ('@RampDnRate', '600'),
#               ('@RampPrice', '0'),
#               ('@RampDeficit', '0'),
#               ('@SemiDispatchCap', 'FALSE')]),
#  OrderedDict([('@TraderID', 'ASNENC1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '18'),
#               ('@R60Target', '39'),
#               ('@R5Target', '37'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '-1029000'),
#               ('@R60Price', '-1029000'),
#               ('@R5Price', '-1029000'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '0'),
#               ('@L5Price', '0'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@R6Flags', '1'),
#               ('@R60Flags', '1'),
#               ('@R5Flags', '1')]),
#  OrderedDict([('@TraderID', 'ASQENC1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '1'),
#               ('@R60Target', '1'),
#               ('@R5Target', '1'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '-1029000'),
#               ('@R60Price', '-1029000'),
#               ('@R5Price', '-1029000'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '0'),
#               ('@L5Price', '0'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@R6Flags', '1'),
#               ('@R60Flags', '1'),
#               ('@R5Flags', '1')]),
#  OrderedDict([('@TraderID', 'ASSEL1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '0'),
#               ('@R60Target', '0'),
#               ('@R5Target', '0'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '0'),
#               ('@R60Price', '-1029000'),
#               ('@R5Price', '-1029000'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '-1029000'),
#               ('@L5Price', '-1029000'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@R60Flags', '1'),
#               ('@R5Flags', '1'),
#               ('@L60Flags', '1'),
#               ('@L5Flags', '1')]),
#  OrderedDict([('@TraderID', 'ASSENC1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '3'),
#               ('@R60Target', '0'),
#               ('@R5Target', '0'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '-1029000'),
#               ('@R60Price', '-1029000'),
#               ('@R5Price', '-1029000'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '0'),
#               ('@L5Price', '0'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@R6Flags', '1'),
#               ('@R60Flags', '1'),
#               ('@R5Flags', '1')]),
#  OrderedDict([('@TraderID', 'ASTHYD1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@EnergyTarget', '0'),
#               ('@R6Target', '27.181'),
#               ('@R60Target', '0'),
#               ('@R5Target', '0'),
#               ('@R5RegTarget', '0'),
#               ('@L6Target', '0'),
#               ('@L60Target', '0'),
#               ('@L5Target', '0'),
#               ('@L5RegTarget', '0'),
#               ('@R6Price', '-1029000'),
#               ('@R60Price', '0'),
#               ('@R5Price', '0'),
#               ('@R5RegPrice', '0'),
#               ('@L6Price', '0'),
#               ('@L60Price', '0'),
#               ('@L5Price', '0'),
#               ('@L5RegPrice', '0'),
#               ('@R6Violation', '0'),
#               ('@R60Violation', '0'),
#               ('@R5Violation', '0'),
#               ('@R5RegViolation', '0'),
#               ('@L6Violation', '0'),
#               ('@L60Violation', '0'),
#               ('@L5Violation', '0'),
#               ('@L5RegViolation', '0'),
#               ('@R6Flags', '1')])]

# %% [markdown]
# #### Constraint Solution
# Very important. Contains RHS values for each constraint. Can use this when formulating program.

# %%
doc['NEMSPDCaseFile']['NemSpdOutputs']['ConstraintSolution'][:10]
# Out:
# [OrderedDict([('@ConstraintID', '#BNGSF2_E'),
#               ('@Version', '20190703000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '20'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#CHILDSF1_E'),
#               ('@Version', '20190903000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '56'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#CLERMSF1_E'),
#               ('@Version', '20190917000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '37.5'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#COOPGWF1_E'),
#               ('@Version', '20190911000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '107'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#CROWLWF1_E'),
#               ('@Version', '20190503000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '72'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#DAYDSF1_E'),
#               ('@Version', '20190614000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '145'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#DEVILS_G_E'),
#               ('@Version', '20190815000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '64'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#FINLYSF1_E'),
#               ('@Version', '20190925000000_2'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '45'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#HAUGHT11_E'),
#               ('@Version', '20190827000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '100'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')]),
#  OrderedDict([('@ConstraintID', '#HAYMSF1_E'),
#               ('@Version', '20190614000000_1'),
#               ('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@Intervention', '0'),
#               ('@RHS', '45'),
#               ('@MarginalValue', '0'),
#               ('@Deficit', '0')])]

# %% [markdown]
# ## Solution Analysis
#
# #### Price Setting
# Contains information regarding price setting generators.

# %%
doc['NEMSPDCaseFile']['SolutionAnalysis']['PriceSetting']
# Out:
# [OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'GSTONE2'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25802'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.443845')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'GSTONE6'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25802'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.443845')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25802'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.443845')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'GSTONE3'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25802'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.443845')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'GSTONE5'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25802'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.443845')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE6,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.45059'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE5,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.45059'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE4,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.45059'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE3,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.45059'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'Energy'),
#               ('@Price', '82.21926'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE2,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.45059'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'R6SE'),
#               ('@Price', '2.29'),
#               ('@Unit', 'APD01'),
#               ('@DispatchedMarket', 'R6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '2.29'),
#               ('@BandCost', '-2.29')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'R60S'),
#               ('@Price', '1'),
#               ('@Unit', 'VP6'),
#               ('@DispatchedMarket', 'R60S'),
#               ('@BandNo', '1'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '1'),
#               ('@BandCost', '-1')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'R5MI'),
#               ('@Price', '0.73'),
#               ('@Unit', 'W/HOE#2'),
#               ('@DispatchedMarket', 'R5MI'),
#               ('@BandNo', '2'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.73'),
#               ('@BandCost', '-0.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'R5RE'),
#               ('@Price', '14.73'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'R5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.73'),
#               ('@BandCost', '-14.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'L6SE'),
#               ('@Price', '0.04'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'L6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.04'),
#               ('@BandCost', '-0.04')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'L60S'),
#               ('@Price', '0.19'),
#               ('@Unit', 'LOYYB2'),
#               ('@DispatchedMarket', 'L60S'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.19'),
#               ('@BandCost', '-0.19')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'L5MI'),
#               ('@Price', '0.44'),
#               ('@Unit', 'MACKNTSH'),
#               ('@DispatchedMarket', 'L5MI'),
#               ('@BandNo', '5'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.44'),
#               ('@BandCost', '-0.44')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'NSW1'),
#               ('@Market', 'L5RE'),
#               ('@Price', '14.73'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'L5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.73'),
#               ('@BandCost', '-14.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'GSTONE2'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.2'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '12.746')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'GSTONE6'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.2'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '12.746')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.2'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '12.746')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'GSTONE3'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.2'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '12.746')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'GSTONE5'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.2'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '12.746')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE6,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000005')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE5,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000005')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE4,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000005')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE3,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000005')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'Energy'),
#               ('@Price', '63.73003'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE2,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000005')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'R6SE'),
#               ('@Price', '2.29'),
#               ('@Unit', 'APD01'),
#               ('@DispatchedMarket', 'R6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '2.29'),
#               ('@BandCost', '-2.29')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'R60S'),
#               ('@Price', '1'),
#               ('@Unit', 'VP6'),
#               ('@DispatchedMarket', 'R60S'),
#               ('@BandNo', '1'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '1'),
#               ('@BandCost', '-1')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'R5MI'),
#               ('@Price', '0.73'),
#               ('@Unit', 'W/HOE#2'),
#               ('@DispatchedMarket', 'R5MI'),
#               ('@BandNo', '2'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.73'),
#               ('@BandCost', '-0.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'R5RE'),
#               ('@Price', '14.73'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'R5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.73'),
#               ('@BandCost', '-14.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'L6SE'),
#               ('@Price', '0.04'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'L6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.04'),
#               ('@BandCost', '-0.04')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'L60S'),
#               ('@Price', '0.19'),
#               ('@Unit', 'LOYYB2'),
#               ('@DispatchedMarket', 'L60S'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.19'),
#               ('@BandCost', '-0.19')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'L5MI'),
#               ('@Price', '0.44'),
#               ('@Unit', 'MACKNTSH'),
#               ('@DispatchedMarket', 'L5MI'),
#               ('@BandNo', '5'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.44'),
#               ('@BandCost', '-0.44')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'QLD1'),
#               ('@Market', 'L5RE'),
#               ('@Price', '14.73'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'L5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.73'),
#               ('@BandCost', '-14.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'GSTONE2'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.22081'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '14.072034')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'GSTONE6'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.22081'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '14.072034')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.22081'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '14.072034')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'GSTONE3'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.22081'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '14.072034')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'GSTONE5'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.22081'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '14.072034')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE6,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5.52018'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE5,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5.52018'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE4,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5.52018'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE3,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5.52018'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'Energy'),
#               ('@Price', '70.3602'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE2,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '5.52018'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'R6SE'),
#               ('@Price', '2.29'),
#               ('@Unit', 'APD01'),
#               ('@DispatchedMarket', 'R6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '2.29'),
#               ('@BandCost', '-2.29')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'R60S'),
#               ('@Price', '1'),
#               ('@Unit', 'VP6'),
#               ('@DispatchedMarket', 'R60S'),
#               ('@BandNo', '1'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '1'),
#               ('@BandCost', '-1')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'R5MI'),
#               ('@Price', '0.73'),
#               ('@Unit', 'W/HOE#2'),
#               ('@DispatchedMarket', 'R5MI'),
#               ('@BandNo', '2'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.73'),
#               ('@BandCost', '-0.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'R5RE'),
#               ('@Price', '14.73'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'R5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.73'),
#               ('@BandCost', '-14.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'L6SE'),
#               ('@Price', '0.04'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'L6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.04'),
#               ('@BandCost', '-0.04')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'L60S'),
#               ('@Price', '0.19'),
#               ('@Unit', 'LOYYB2'),
#               ('@DispatchedMarket', 'L60S'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.19'),
#               ('@BandCost', '-0.19')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'L5MI'),
#               ('@Price', '0.44'),
#               ('@Unit', 'MACKNTSH'),
#               ('@DispatchedMarket', 'L5MI'),
#               ('@BandNo', '5'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.44'),
#               ('@BandCost', '-0.44')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'SA1'),
#               ('@Market', 'L5RE'),
#               ('@Price', '14.73'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'L5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.73'),
#               ('@BandCost', '-14.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'W/HOE#2'),
#               ('@DispatchedMarket', 'R5MI'),
#               ('@BandNo', '2'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.73'),
#               ('@BandCost', '-0.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'VP6'),
#               ('@DispatchedMarket', 'R60S'),
#               ('@BandNo', '1'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '1'),
#               ('@BandCost', '-1')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'GSTONE2'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.26478'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.874261')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'R5MI'),
#               ('@BandNo', '2'),
#               ('@Increase', '1'),
#               ('@RRNBandPrice', '0.7'),
#               ('@BandCost', '0.7')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'R60S'),
#               ('@BandNo', '2'),
#               ('@Increase', '1'),
#               ('@RRNBandPrice', '0.49'),
#               ('@BandCost', '0.49')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'T-V-MNSP1,TAS1'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '1'),
#               ('@Increase', '1'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'GSTONE6'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.26478'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.874261')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.26478'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.874261')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'GSTONE3'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.26478'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.874261')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'GSTONE5'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.26478'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.874261')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE6,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.61943'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000007')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE5,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.61943'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000007')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE4,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.61943'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000007')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE3,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.61943'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000007')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'Energy'),
#               ('@Price', '83.83134'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE2,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.61943'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000007')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'R6SE'),
#               ('@Price', '10'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'R6SE'),
#               ('@BandNo', '6'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '10'),
#               ('@BandCost', '-10')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'R60S'),
#               ('@Price', '0.49'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'R60S'),
#               ('@BandNo', '2'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.49'),
#               ('@BandCost', '-0.49')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'R5MI'),
#               ('@Price', '0.7'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'R5MI'),
#               ('@BandNo', '2'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.7'),
#               ('@BandCost', '-0.7')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'R5RE'),
#               ('@Price', '14.5'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'R5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.5'),
#               ('@BandCost', '-14.5')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'L6SE'),
#               ('@Price', '0.04'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'L6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.04'),
#               ('@BandCost', '-0.04')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'L60S'),
#               ('@Price', '0.19'),
#               ('@Unit', 'LOYYB2'),
#               ('@DispatchedMarket', 'L60S'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.19'),
#               ('@BandCost', '-0.19')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'L5MI'),
#               ('@Price', '0.44'),
#               ('@Unit', 'MACKNTSH'),
#               ('@DispatchedMarket', 'L5MI'),
#               ('@BandNo', '5'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.44'),
#               ('@BandCost', '-0.44')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'TAS1'),
#               ('@Market', 'L5RE'),
#               ('@Price', '14'),
#               ('@Unit', 'LEM_WIL'),
#               ('@DispatchedMarket', 'L5RE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14'),
#               ('@BandCost', '-14')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'GSTONE2'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25731'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.398258')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'GSTONE6'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25731'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.398258')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25731'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.398258')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'GSTONE3'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25731'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.398258')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'GSTONE5'),
#               ('@DispatchedMarket', 'ENOF'),
#               ('@BandNo', '5'),
#               ('@Increase', '0.25731'),
#               ('@RRNBandPrice', '63.73'),
#               ('@BandCost', '16.398258')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE6,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.43271'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE5,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.43271'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE4,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.43271'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE3,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.43271'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'Energy'),
#               ('@Price', '81.99132'),
#               ('@Unit', 'ENOF,GSTONE1,5,GSTONE2,5'),
#               ('@DispatchedMarket', 'tbslack2'),
#               ('@Increase', '6.43271'),
#               ('@RRNBandPrice', '0'),
#               ('@BandCost', '0.000006')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'R6SE'),
#               ('@Price', '2.29'),
#               ('@Unit', 'APD01'),
#               ('@DispatchedMarket', 'R6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '2.29'),
#               ('@BandCost', '-2.29')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'R60S'),
#               ('@Price', '1'),
#               ('@Unit', 'VP6'),
#               ('@DispatchedMarket', 'R60S'),
#               ('@BandNo', '1'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '1'),
#               ('@BandCost', '-1')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'R5MI'),
#               ('@Price', '0.73'),
#               ('@Unit', 'W/HOE#2'),
#               ('@DispatchedMarket', 'R5MI'),
#               ('@BandNo', '2'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.73'),
#               ('@BandCost', '-0.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'R5RE'),
#               ('@Price', '14.73'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'R5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.73'),
#               ('@BandCost', '-14.73')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'L6SE'),
#               ('@Price', '0.04'),
#               ('@Unit', 'GORDON'),
#               ('@DispatchedMarket', 'L6SE'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.04'),
#               ('@BandCost', '-0.04')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'L60S'),
#               ('@Price', '0.19'),
#               ('@Unit', 'LOYYB2'),
#               ('@DispatchedMarket', 'L60S'),
#               ('@BandNo', '4'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.19'),
#               ('@BandCost', '-0.19')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'L5MI'),
#               ('@Price', '0.44'),
#               ('@Unit', 'MACKNTSH'),
#               ('@DispatchedMarket', 'L5MI'),
#               ('@BandNo', '5'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '0.44'),
#               ('@BandCost', '-0.44')]),
#  OrderedDict([('@PeriodID', '2019-10-01T04:05:00+10:00'),
#               ('@RegionID', 'VIC1'),
#               ('@Market', 'L5RE'),
#               ('@Price', '14.73'),
#               ('@Unit', 'GSTONE4'),
#               ('@DispatchedMarket', 'L5RE'),
#               ('@BandNo', '3'),
#               ('@Increase', '-1'),
#               ('@RRNBandPrice', '14.73'),
#               ('@BandCost', '-14.73')])]

# %% [markdown]
# ## Observations

# %% [markdown]
# ## Design
# Tasks:
# 1. Determine appropriate representation for LHS variables
#
# Steps to construct NEMDE approximation:
# 1. Extract all variables
# 2. Extract RHS constants
# 3. Extract price band information for each participant (generator, load, interconnectors)
# 4. X - Extract quantity band information for each participant (generator, load, interconnectors)
# 5. Construct objective
# 6. Construct constraints
# 7. Solve model
#
# Steps to check model:
# 1. Extract objective value
# 2. Extract energy output solution (intervention = 0)
# 3. Extract prices for each region
# 4. Compare objective value
# 5. Compare dispatch with NEMDE dispatch solution

# %%
def get_quantity_bands(doc):
    """Get quantity bands for each bid type"""

    # Container for quantity bands
    quantity_bands = dict()

    # Loop through each generator
    for i in doc['NEMSPDCaseFile']['NemSpdInputs']['PeriodCollection']['Period']['TraderPeriodCollection']['TraderPeriod']:
        
        # Extract quantity band for each trade type and extract as dictionary
        if type(i['TradeCollection']['Trade']) == collections.OrderedDict:
            quantity_bands[i['@TraderID']] = {i['TradeCollection']['Trade']['@TradeType']: i['TradeCollection']['Trade']}

        elif type(i['TradeCollection']['Trade']) == list:
            quantity_bands[i['@TraderID']] = {j['@TradeType']: j for j in i['TradeCollection']['Trade']}
            
    return quantity_bands

q_bands = get_quantity_bands(doc)

# %%
price_bands = dict()

for u in doc['NEMSPDCaseFile']['NemSpdInputs']['TraderCollection']['Trader']:
    # Extract price structure information
    if type(u['TradeCollection']['Trade']) == collections.OrderedDict:
        price_bands[u['@TraderID']] = {price_structure['@TradeType']: u['TradePriceStructureCollection']['TradePriceStructure']['TradeTypePriceStructureCollection']['TradeTypePriceStructure']}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-035418519ebd> in <module>
#       3 for u in doc['NEMSPDCaseFile']['NemSpdInputs']['TraderCollection']['Trader']:
#       4     # Extract price structure information
# ----> 5     if type(u['TradeCollection']['Trade']) == collections.OrderedDict:
#       6         price_bands[u['@TraderID']] = {price_structure['@TradeType']: u['TradePriceStructureCollection']['TradePriceStructure']['TradeTypePriceStructureCollection']['TradeTypePriceStructure']}
#       7
#
# KeyError: 'TradeCollection'

# %%
u['TradePriceStructureCollection']['TradePriceStructure']['TradeTypePriceStructureCollection']['TradeTypePriceStructure']
# Out:
# OrderedDict([('@TradeType', 'ENOF'),
#              ('@PriceBand1', '-1000'),
#              ('@PriceBand2', '0'),
#              ('@PriceBand3', '278.81'),
#              ('@PriceBand4', '368.81'),
#              ('@PriceBand5', '418.81'),
#              ('@PriceBand6', '498.81'),
#              ('@PriceBand7', '578.81'),
#              ('@PriceBand8', '1365.56'),
#              ('@PriceBand9', '10578.87'),
#              ('@PriceBand10', '13998.99'),
#              ('@Offer_SettlementDate', '2019-10-01T00:00:00+10:00'),
#              ('@Offer_EffectiveDate', '2019-09-23T10:30:35+10:00'),
#              ('@Offer_VersionNo', '1')])
